# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#Rotten Tomatoes datasets
rot_info = pd.read_csv('zippedData/rt.movie_info.tsv.gz', sep='\t')
#rot_ratings = pd.read_csv('zippedData/rt.reviews.tsv.gz')

#imdb datasets
imdb_ratings = pd.read_csv('zippedData/imdb.title.ratings.csv.gz')
#imdb_title_principals = pd.read_csv('zippedData/imdb.title.principals.csv.gz')
imdb_titles = pd.read_csv('zippedData/imdb.title.basics.csv.gz')

#box office mojo
bojo_gross = pd.read_csv('zippedData/bom.movie_gross.csv')

#the movied data base
tmdb = pd.read_csv('zippedData/tmdb.movies.csv.gz')

# %%
#joining

# %% [markdown]
# # Objective #1: Which genres of movie have the highest rating?

# %% [markdown]
# ## Visual #1: IMDB Highest Rated Movie Genres

# %%
#For first analysis, I am going to combine the imdb titles and ratings datasets. 
# Sort by last five years and then create a scatterplot. 

#setting indexes to 'tconst' for each dataset
imdb_titles.set_index('tconst', inplace=True)
imdb_ratings.set_index('tconst', inplace=True)

# %%
#joining dfs using inner join to get movies that contain both titles and ratings
imdb_titles_ratings = imdb_titles.join(imdb_ratings, how='inner')

# %%
imdb_titles_ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73856 entries, tt0063540 to tt9916160
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   primary_title    73856 non-null  object
#  1   original_title   73856 non-null  object
#  2   start_year       73856 non-null  int64
#  3   runtime_minutes  66236 non-null  float64
#  4   genres           73052 non-null  object
#  5   averagerating    73856 non-null  float64
#  6   numvotes         73856 non-null  int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
#filters data so that it is only movies from 2018 & 2019 with more than 100 reviews
recent_ratings = imdb_titles_ratings[(imdb_titles_ratings['start_year'] >= 2010)
                                    & (imdb_titles_ratings['numvotes'] >= 100)]

# %%
genre_types = recent_ratings['genres'].value_counts()
genres_df = pd.DataFrame(genre_types)
genres_df.reset_index(inplace=True)
genres_df = genres_df.rename(columns={'index': 'genre', 'genres': 'movie_count'})

# %%
#Creates a list of top 25 genres with goal of filtering data so that it includes
# top 25 genres with 50 or more reviews from 2018 and 2019
top_25_genres = genres_df.iloc[:25]
top_25_genres
# Out:
#                          genre  movie_count
# 0                        Drama         3964
# 1                       Comedy         2338
# 2                  Documentary         1785
# 3                 Comedy,Drama         1378
# 4                       Horror          857
# 5                Drama,Romance          810
# 6               Comedy,Romance          749
# 7         Comedy,Drama,Romance          698
# 8              Horror,Thriller          608
# 9                     Thriller          548
# 10              Drama,Thriller          520
# 11          Action,Crime,Drama          335
# 12        Crime,Drama,Thriller          310
# 13                      Action          308
# 14                 Crime,Drama          252
# 15     Horror,Mystery,Thriller          234
# 16               Comedy,Horror          229
# 17             Action,Thriller          226
# 18                Action,Drama          206
# 19                     Romance          203
# 20       Action,Crime,Thriller          195
# 21  Adventure,Animation,Comedy          194
# 22           Documentary,Music          187
# 23               Action,Comedy          181
# 24       Drama,Horror,Thriller          175

# %%
#See if group_by works to filter by genre in larger dataset
filt = recent_ratings['genres'].isin(top_25_genres['genre'])
top_25_genres_ratings = recent_ratings[filt]
top_25_genres_ratings[['primary_title', 'genres', 'averagerating', 'numvotes']]
# Out:
#                           primary_title                      genres  \
# tconst
# tt0069049    The Other Side of the Wind                       Drama
# tt0137204               Joe Finds Grace  Adventure,Animation,Comedy
# tt0146592                   Pál Adrienn                       Drama
# tt0162942  Children of the Green Dragon                       Drama
# tt0250404                     Godfather                 Crime,Drama
# ...                                 ...                         ...
# tt9903716                        Jessie             Horror,Thriller
# tt9904844          Ott Tänak: The Movie                 Documentary
# tt9905412                         Ottam                       Drama
# tt9905462                     Pengalila                       Drama
# tt9911774     Padmavyuhathile Abhimanyu                       Drama
#
#            averagerating  numvotes
# tconst
# tt0069049            6.9      4517
# tt0137204            8.1       263
# tt0146592            6.8       451
# tt0162942            6.9       120
# tt0250404            6.7       236
# ...                  ...       ...
# tt9903716            8.5       100
# tt9904844            8.7       218
# tt9905412            8.1       505
# tt9905462            8.4       600
# tt9911774            8.4       365
#
# [17490 rows x 4 columns]

# %%
#Final database that only includes movies in the top 25 genres since 2018 with more than 50 votes
top_25_genres_ratings = top_25_genres_ratings.groupby('genres').mean()
top_25_genres_ratings.sort_values(by='averagerating', ascending=False, inplace=True)
top_25_genres_ratings = top_25_genres_ratings[['averagerating', 'numvotes']]
top_25_genres_ratings
# Out:
#                             averagerating      numvotes
# genres
# Documentary,Music                7.252941   2047.684492
# Documentary                      7.021289    896.056583
# Drama                            6.320787   2062.817608
# Crime,Drama                      6.280556  11843.099206
# Drama,Romance                    6.208519   6814.198765
# Comedy,Drama                     6.141800   4660.356313
# Comedy,Drama,Romance             6.064613  10960.329513
# Adventure,Animation,Comedy       6.021134  44770.587629
# Crime,Drama,Thriller             5.950000  10827.219355
# Action,Drama                     5.938350   3673.276699
# Romance                          5.925616    616.354680
# Action,Crime,Drama               5.852239  16586.050746
# Drama,Thriller                   5.826154   7432.948077
# Action,Crime,Thriller            5.764615  25328.794872
# Action,Thriller                  5.714602  18941.424779
# Comedy,Romance                   5.687183   6321.285714
# Action,Comedy                    5.477901   5462.154696
# Comedy                           5.327545   2880.262618
# Thriller                         5.237591    749.872263
# Action                           5.162338   1014.353896
# Drama,Horror,Thriller            4.870286   5795.000000
# Horror,Mystery,Thriller          4.785470  16658.897436
# Comedy,Horror                    4.727074   3797.934498
# Horror,Thriller                  4.550493   5086.628289
# Horror                           4.251459   1787.980163

# %%
fig, ax = plt.subplots(figsize=(10,4))

average_rating = top_25_genres_ratings['averagerating']

ax.bar(top_25_genres_ratings.index, average_rating.values)

ax.tick_params(axis='x', labelrotation=90)

# %%
#x-variable for ease of use
average_rating = top_25_genres_ratings['averagerating']

#pallete preparation
#sns.color_palette(palette='viridis', n_colors=25, as_cmap=True)

ax = sns.barplot(y=top_25_genres_ratings.index, x=average_rating, palette='viridis')
#color palletes i like: 'viridis'

ax.get_figure().set_size_inches((11, 8.5))
ax.set_xlabel('Average Rating (out of 10.0)')
ax.set_ylabel(ylabel=None)
ax.set_title("Average Rating of Top 25 Movie Genres from 2010-2019 (source iMDB)");

# %% [markdown]
# ### Possible Seaborn Palletes:
#
# 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r'

# %% [markdown]
# ## Visual #2: Rotten Tomatoes Top Rated Movie Genres

# %%
rot_info.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      NaN
# 4                     Giles Cooper           NaN           NaN      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
#extracting relevant df columns
rot_info1 = rot_info[['id', 'genre', 'theater_date']]
#Setting index to movie id to allow for joining with review dataset
rot_info1.set_index('id', inplace=True)

# %%
#consulted slack, code below allows gzip file to be compressed and read
df_reviews = pd.read_csv('zippedData/rt.reviews.tsv', delimiter='\t', encoding='iso-8859-1')
#, compression='gzip'

# %%
rt_reviews = df_reviews[['id', 'rating', 'fresh']]
rt_reviews.set_index('id', inplace=True)

# %%
#executing left join so that all the reviews are included to corresponding movie ids
rt_reviews_info = rt_reviews.join(rot_info1, how='left')
rt_reviews_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 54432 entries, 3 to 2000
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rating        40915 non-null  object
#  1   fresh         54432 non-null  object
#  2   genre         54345 non-null  object
#  3   theater_date  53206 non-null  object
# dtypes: object(4)
# memory usage: 2.1+ MB

# %%
#filter results further, so that it only includes movies released since 2010
#requires a map method to remove everything but the four digits of the year of release

#Deciding to drop the data that doesn't have any data attached. Dropped data accounts
#for 3% of total data at this point of cleaning
rt_reviews_info.dropna(subset=['theater_date'], inplace=True)

#creates new column that only includes the year
rt_reviews_info['year_release'] = rt_reviews_info['theater_date'].map(lambda x: x[-4:])

#changes the column from objects into ints
rt_reviews_info['year_release'] = pd.to_numeric(rt_reviews_info['year_release'])
rt_reviews_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 53206 entries, 3 to 2000
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rating        40015 non-null  object
#  1   fresh         53206 non-null  object
#  2   genre         53206 non-null  object
#  3   theater_date  53206 non-null  object
#  4   year_release  53206 non-null  int64
# dtypes: int64(1), object(4)
# memory usage: 2.4+ MB

# %%
#now filtering the data by years from 2010 onward
filt = (rt_reviews_info['year_release'] >= 2010)
recent_rt_reviews = rt_reviews_info.loc[filt].copy()

recent_rt_reviews.head()
# Out:
#    rating   fresh                              genre  theater_date  \
# id
# 3     3/5   fresh  Drama|Science Fiction and Fantasy  Aug 17, 2012
# 3     NaN  rotten  Drama|Science Fiction and Fantasy  Aug 17, 2012
# 3     NaN   fresh  Drama|Science Fiction and Fantasy  Aug 17, 2012
# 3     NaN   fresh  Drama|Science Fiction and Fantasy  Aug 17, 2012
# 3     NaN   fresh  Drama|Science Fiction and Fantasy  Aug 17, 2012
#
#     year_release
# id
# 3           2012
# 3           2012
# 3           2012
# 3           2012
# 3           2012

# %%
#there is no standard rating system besides the fresh or rotten rating.
#so, my plan is to change the 'fresh' into 1 and 'rotten' into 0 and then find the
#average of each movie

recent_rt_reviews['fresh_numeric'] = recent_rt_reviews['fresh'].map(lambda x: 1 if x == 'fresh' else 0)

#recent_rt_reviews.loc[recent_rt_reviews.fresh] = recent_rt_reviews.fresh.map(lambda x: 1 if x == 'fresh' else 0)

# %%
recent_rt_reviews
# Out:
#      rating   fresh                                             genre  \
# id
# 3       3/5   fresh                 Drama|Science Fiction and Fantasy
# 3       NaN  rotten                 Drama|Science Fiction and Fantasy
# 3       NaN   fresh                 Drama|Science Fiction and Fantasy
# 3       NaN   fresh                 Drama|Science Fiction and Fantasy
# 3       NaN   fresh                 Drama|Science Fiction and Fantasy
# ...     ...     ...                                               ...
# 1976    NaN   fresh  Action and Adventure|Art House and International
# 1981    3/5   fresh                                      Comedy|Drama
# 1981    NaN   fresh                                      Comedy|Drama
# 1981    2/4  rotten                                      Comedy|Drama
# 1981    3/5   fresh                                      Comedy|Drama
#
#       theater_date  year_release  fresh_numeric
# id
# 3     Aug 17, 2012          2012              1
# 3     Aug 17, 2012          2012              0
# 3     Aug 17, 2012          2012              1
# 3     Aug 17, 2012          2012              1
# 3     Aug 17, 2012          2012              1
# ...            ...           ...            ...
# 1976  Feb 17, 2016          2016              1
# 1981   Oct 5, 2012          2012              1
# 1981   Oct 5, 2012          2012              1
# 1981   Oct 5, 2012          2012              0
# 1981   Oct 5, 2012          2012              1
#
# [17252 rows x 6 columns]

# %%
# reviews_genre_mean = recent_rt_reviews.groupby('genre').mean().copy()
# reviews_genre_mean.reset_index(inplace=True)
# reviews_genre_mean

# %%
rt_top_25_genres = pd.DataFrame(recent_rt_reviews['genre'].value_counts())
rt_top_25_genres = rt_top_25_genres.iloc[:25]
rt_top_25_genres.reset_index(inplace=True)

rt_top_25_genres
# Out:
#                                                 index  genre
# 0                                               Drama   4094
# 1                                        Comedy|Drama   1678
# 2                                              Comedy   1618
# 3                          Drama|Mystery and Suspense   1076
# 4                                       Drama|Romance    740
# 5                                Comedy|Drama|Romance    528
# 6                                      Comedy|Romance    524
# 7                                              Horror    455
# 8           Action and Adventure|Mystery and Suspense    432
# 9    Action and Adventure|Science Fiction and Fantasy    432
# 10                  Drama|Science Fiction and Fantasy    261
# 11                   Animation|Comedy|Kids and Family    232
# 12   Mystery and Suspense|Science Fiction and Fantasy    217
# 13  Action and Adventure|Horror|Science Fiction an...    215
# 14                                       Drama|Horror    214
# 15        Action and Adventure|Comedy|Kids and Family    208
# 16  Action and Adventure|Comedy|Science Fiction an...    189
# 17                                   Animation|Comedy    185
# 18     Action and Adventure|Animation|Kids and Family    185
# 19  Action and Adventure|Horror|Kids and Family|Sc...    182
# 20                                     Comedy|Western    174
# 21    Action and Adventure|Drama|Mystery and Suspense    165
# 22  Comedy|Kids and Family|Science Fiction and Fan...    164
# 23  Action and Adventure|Mystery and Suspense|Romance    153
# 24          Art House and International|Drama|Romance    148

# %%
filt = recent_rt_reviews['genre'].isin(rt_top_25_genres['index'])
rt_top_25_genres_ratings = recent_rt_reviews.loc[filt]

rt_top_25 = rt_top_25_genres_ratings.groupby('genre').mean('fresh_numeric')

#rt_top_25_genres_ratings.sort_values(by='fresh_numeric', ascending=False, inplace=True)

# %%
rt_top_25.sort_values(by='fresh_numeric', ascending=False, inplace=True)

# %%
rt_top_25
# Out:
#                                                     year_release  \
# genre
# Drama|Horror                                         2017.000000
# Action and Adventure|Animation|Kids and Family       2011.000000
# Drama|Romance                                        2016.382432
# Animation|Comedy                                     2016.000000
# Art House and International|Drama|Romance            2017.000000
# Action and Adventure|Drama|Mystery and Suspense      2011.000000
# Drama|Mystery and Suspense                           2013.005576
# Action and Adventure|Mystery and Suspense            2011.212963
# Action and Adventure|Comedy|Kids and Family          2018.000000
# Comedy|Drama                                         2013.830751
# Drama                                                2014.669761
# Comedy|Drama|Romance                                 2010.492424
# Comedy|Kids and Family|Science Fiction and Fantasy   2018.000000
# Comedy|Romance                                       2012.778626
# Comedy                                               2013.810878
# Drama|Science Fiction and Fantasy                    2012.750958
# Animation|Comedy|Kids and Family                     2017.025862
# Action and Adventure|Horror|Kids and Family|Sci...   2012.000000
# Horror                                               2014.167033
# Action and Adventure|Science Fiction and Fantasy     2013.840278
# Action and Adventure|Comedy|Science Fiction and...   2011.000000
# Comedy|Western                                       2014.000000
# Action and Adventure|Horror|Science Fiction and...   2018.000000
# Action and Adventure|Mystery and Suspense|Romance    2010.000000
# Mystery and Suspense|Science Fiction and Fantasy     2018.000000
#
#                                                     fresh_numeric
# genre
# Drama|Horror                                             0.878505
# Action and Adventure|Animation|Kids and Family           0.870270
# Drama|Romance                                            0.854054
# Animation|Comedy                                         0.821622
# Art House and International|Drama|Romance                0.797297
# Action and Adventure|Drama|Mystery and Suspense          0.769697
# Drama|Mystery and Suspense                               0.744424
# Action and Adventure|Mystery and Suspense                0.717593
# Action and Adventure|Comedy|Kids and Family              0.716346
# Comedy|Drama                                             0.706198
# Drama                                                    0.693698
# Comedy|Drama|Romance                                     0.659091
# Comedy|Kids and Family|Science Fiction and Fantasy       0.658537
# Comedy|Romance                                           0.612595
# Comedy                                                   0.605686
# Drama|Science Fiction and Fantasy                        0.590038
# Animation|Comedy|Kids and Family                         0.564655
# Action and Adventure|Horror|Kids and Family|Sci...       0.549451
# Horror                                                   0.529670
# Action and Adventure|Science Fiction and Fantasy         0.502315
# Action and Adventure|Comedy|Science Fiction and...       0.460317
# Comedy|Western                                           0.327586
# Action and Adventure|Horror|Science Fiction and...       0.320930
# Action and Adventure|Mystery and Suspense|Romance        0.209150
# Mystery and Suspense|Science Fiction and Fantasy         0.175115

# %%
#x-variable for ease of use
rt_average_rating = rt_top_25['fresh_numeric']

#pallete preparation
#sns.color_palette(palette='viridis', n_colors=25, as_cmap=True)

ax = sns.barplot(y=rt_top_25.index, x=rt_average_rating, palette='viridis')
#color palletes i like: 'viridis'

ax.get_figure().set_size_inches((11, 8.5))
ax.set_xlabel('Rate of Certified Fresh')
ax.set_ylabel(ylabel=None)
ax.set_title("Average Rating of Top 25 Movie Genres from 2010-2018 (source iMDB)");

# %% [markdown]
# # Objective #2: What movies/ types of movies are most successful and gross the most money?

# %% [markdown]
# ## Top 25 Grossing Films Visual (BoJo)

# %%
top_gross = bojo_gross.sort_values(by='domestic_gross', ascending=False)[:25].copy()

# %%
#x-variable for ease of use
dom_gross_amount = top_gross['domestic_gross']

titles = top_gross['title']

#pallete preparation
#sns.color_palette(palette='viridis', n_colors=25, as_cmap=True)

ax1 = sns.barplot(y=titles, x=dom_gross_amount, palette='viridis')
#color palletes i like: 'viridis'

ax1.get_figure().set_size_inches((11, 8.5))
ax1.set_xlabel('Amount ($) Grossed')
ax1.xaxis.set_major_formatter("{x:,.2f}")
ax1.set_ylabel(ylabel=None)
ax1.set_title("Top Grossing Films (Domestic Gross)");

# %% [markdown]
# ## Top 25 Movies (ratings and popularity) visuals (TMDB)

# %%
popular_movies = tmdb.sort_values(by='popularity', ascending=False)[:25].copy()

tmdb.head()
# Out:
#    Unnamed: 0            genre_ids     id original_language  \
# 0           0      [12, 14, 10751]  12444                en
# 1           1  [14, 12, 16, 10751]  10191                en
# 2           2        [12, 28, 878]  10138                en
# 3           3      [16, 35, 10751]    862                en
# 4           4        [28, 878, 12]  27205                en
#
#                                  original_title  popularity release_date  \
# 0  Harry Potter and the Deathly Hallows: Part 1      33.533   2010-11-19
# 1                      How to Train Your Dragon      28.734   2010-03-26
# 2                                    Iron Man 2      28.515   2010-05-07
# 3                                     Toy Story      28.005   1995-11-22
# 4                                     Inception      27.920   2010-07-16
#
#                                           title  vote_average  vote_count
# 0  Harry Potter and the Deathly Hallows: Part 1           7.7       10788
# 1                      How to Train Your Dragon           7.7        7610
# 2                                    Iron Man 2           6.8       12368
# 3                                     Toy Story           7.9       10174
# 4                                     Inception           8.3       22186

# %%
#x-variable for ease of use
tmdb_ratings = popular_movies['vote_average']
tmdb_popularity = popular_movies['popularity']
titles = popular_movies['original_title']

#pallete preparation
#sns.color_palette(palette='viridis', n_colors=25, as_cmap=True)

ax1 = sns.barplot(y=titles, x=tmdb_popularity, palette = 'viridis')
#color palletes i like: 'viridis'

ax1.get_figure().set_size_inches((11, 8.5))
ax1.set_xlabel('Popularity')
ax1.set_ylabel(ylabel=None)
ax1.set_title("Top 25 most popular movies from 2010-2018 (source iMDB)");

# %%
ax2 = sns.barplot(y=titles, x=tmdb_ratings, palette='viridis')
#color palletes i like: 'viridis'

ax2.get_figure().set_size_inches((11, 8.5))
ax2.set_xlabel('Ratings')
ax2.set_ylabel(ylabel=None)
ax2.set_title("Top 25 Most Popular Movies Ratings");

# %% [markdown]
# ## Combing Popularity/Ratings and Domestic Gross

# %%
#Setting both indexes to title
bojo_cpy = bojo_gross.set_index('title').copy()
tmdb_cpy = tmdb.set_index('title').copy()
#using inner join to see which films to allow graphing relation between ratings/popularity
#and domestic gross
joined_dfs = bojo_cpy.join(tmdb_cpy, how='inner')

# %%
bojo_tmdb = joined_dfs[['domestic_gross', 'year', 'popularity', 'vote_average', 
                        'vote_count']].copy()

#2703 movie 'survived' the inner join 
bojo_tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2703 entries, '71 to mother!
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   domestic_gross  2682 non-null   float64
#  1   year            2703 non-null   int64
#  2   popularity      2703 non-null   float64
#  3   vote_average    2703 non-null   float64
#  4   vote_count      2703 non-null   int64
# dtypes: float64(3), int64(2)
# memory usage: 126.7+ KB

# %%
filt = (bojo_tmdb['popularity'] > 1) & (bojo_tmdb['vote_count'] > 100) & (bojo_tmdb['domestic_gross'] > 1000000)
bojo_tmdb = bojo_tmdb.loc[filt].copy()

bojo_tmdb.sort_values(by='domestic_gross')
# Out:
#                               domestic_gross  year  popularity  vote_average  \
# title
# Red State                          1100000.0  2011       7.816           6.1
# Thanks for Sharing                 1100000.0  2013       6.188           5.8
# Elvis & Nixon                      1100000.0  2016       7.857           5.8
# Wildlife                           1100000.0  2018      10.851           6.8
# Timbuktu                           1100000.0  2015       7.372           7.0
# ...                                      ...   ...         ...           ...
# Jurassic World                   652300000.0  2015      20.709           6.6
# Avengers: Infinity War           678800000.0  2018      80.773           8.3
# Black Panther                    700100000.0  2018      44.140           7.4
# Star Wars: The Force Awakens     936700000.0  2015      32.281           7.4
# Star Wars: The Force Awakens     936700000.0  2015      32.281           7.4
#
#                               vote_count
# title
# Red State                            472
# Thanks for Sharing                   302
# Elvis & Nixon                        233
# Wildlife                             151
# Timbuktu                             255
# ...                                  ...
# Jurassic World                     14056
# Avengers: Infinity War             13948
# Black Panther                      12365
# Star Wars: The Force Awakens       12641
# Star Wars: The Force Awakens       12641
#
# [1472 rows x 5 columns]

# %%
#Now attempting a join between bojo gross and imdb database using the 'recent_ratings db'
#create earlier (dbs with more than 100 votes since 2010), which coincides with the time
#intervals of bojo_gross db
imdb_ratings_cpy = recent_ratings.set_index('primary_title').copy()

joined_dfs2 = bojo_cpy.join(imdb_ratings_cpy, how='inner')
joined_dfs2.head()

bojo_imdb = joined_dfs2[['domestic_gross', 'year', 'genres', 'averagerating', 
                        'numvotes']].copy()

# %%
#imdb ratings produces 2762 overlapping entries. So slightly higher sample 
#than merging with tmdb. Also includes 19 values without domestic gross
bojo_imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2762 entries, '71 to Zootopia
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   domestic_gross  2743 non-null   float64
#  1   year            2762 non-null   int64
#  2   genres          2762 non-null   object
#  3   averagerating   2762 non-null   float64
#  4   numvotes        2762 non-null   int64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 129.5+ KB

# %%
### TMDB SCATTERPLOT
#Now to create plots that visualize the relationship between ratings or popularity (x axis) 
# and domestic_gross (y-axis)

#a sns scatterplot will be best in this situation
#x-variable for ease of use
popularity = bojo_tmdb['popularity']
domestic_gross = bojo_tmdb['domestic_gross']

#pallete preparation
#sns.color_palette(palette='viridis', n_colors=25, as_cmap=True)

dict(color='black', ls='--')
ax1 = sns.regplot(y=domestic_gross, x=popularity, marker='o',
                  line_kws= {'color': 'black', 'ls': '--'}, scatter_kws= dict(alpha=0.7, s=5))
#color palletes i like: 'viridis'

ax1.get_figure().set_size_inches((11, 8.5))
ax1.set_xlabel('Popularity')
ax1.set_ylabel('Domestic Gross')
ax1.set_xlim(right=60)
ax1.yaxis.set_major_formatter("${x:,.0f}")
#ax1.yaxis.set_minor_formatter("{y:,.2f}")
ax1.set_title("Popularity vs Domestic Gross (TMDB)");

# %%
###IMDB SCATTERPLOT
rating = bojo_imdb['averagerating']
domestic_gross = bojo_imdb['domestic_gross']

#pallete preparation
#sns.color_palette(palette='viridis', n_colors=25, as_cmap=True)

ax2 = sns.scatterplot(y=domestic_gross, x=rating, alpha=(0.3))
#color palletes i like: 'viridis'

ax2.get_figure().set_size_inches((11, 8.5))
ax2.set_xlabel('Rating')
ax2.set_ylabel('Domestic Gross')
#ax1.xaxis.set_major_formatter("{x:,.2f}")
#ax2.yaxis.set_minor_formatter("{y:,.2f}")
ax2.set_title("Movie Rating vs Domestic Gross (iMDB)");

# %% [markdown]
# # Objective #3: What are the most popular movies currently? And during 2020-2021?

# %%
#For this objective, I am going to be doing an api search using https://imdb-api.com/.

#importing relevant modules 
import requests

# %%
#Acquiring the most popular movies DB
r = requests.get("https://imdb-api.com/en/API/MostPopularMovies/k_4k2gioan")
r.status_code
# Out:
# 200

# %%
response = r.json()
response.keys()
# Out:
# dict_keys(['items', 'errorMessage'])

# %%
#Includes top 100 movies
len(response['items'])

data_list = response['items']
column_names = list(data_list[0].keys())
column_names
# Out:
# ['id',
#  'rank',
#  'rankUpDown',
#  'title',
#  'fullTitle',
#  'year',
#  'image',
#  'crew',
#  'imDbRating',
#  'imDbRatingCount']

# %%
#transforming file into pandas df
most_popular_df = pd.DataFrame(data=data_list, columns=column_names)
most_popular_df.head(25)
# Out:
#             id rank rankUpDown                        title  \
# 0    tt1160419    1          0                         Dune
# 1    tt0087182    2         +4                         Dune
# 2    tt9032400    3         +6                     Eternals
# 3    tt2382320    4          0               No Time to Die
# 4   tt10665338    5         -2              Halloween Kills
# 5    tt8847712    6         +8          The French Dispatch
# 6    tt9639470    7        +17           Last Night in Soho
# 7    tt4244994    8         -3                The Last Duel
# 8   tt10298810    9      2,197                    Lightyear
# 9   tt10763820   10         +2                  Night Teeth
# 10  tt13024674   11       +847              Army of Thieves
# 11   tt7097896   12         -5  Venom: Let There Be Carnage
# 12   tt6264654   13         -5                     Free Guy
# 13   tt7740510   14        +28                      Antlers
# 14  tt12383460   15       +751                     Hypnotic
# 15  tt11001074   16         -5                         Rust
# 16   tt0107120   17        +11                  Hocus Pocus
# 17   tt0077651   18         -5                    Halloween
# 18   tt1877830   19        -17                   The Batman
# 19   tt7991608   20         -1                   Red Notice
# 20   tt1464335   21         -1                    Uncharted
# 21  tt10872600   22        +16      Spider-Man: No Way Home
# 22  tt13069986   23         +4                After We Fell
# 23   tt3480822   24         -7                  Black Widow
# 24  tt10521092   25        -15         The Forgotten Battle
#
#                              fullTitle  year  \
# 0                          Dune (2021)  2021
# 1                          Dune (1984)  1984
# 2                      Eternals (2021)  2021
# 3                No Time to Die (2021)  2021
# 4               Halloween Kills (2021)  2021
# 5           The French Dispatch (2021)  2021
# 6            Last Night in Soho (2021)  2021
# 7                 The Last Duel (2021)  2021
# 8                     Lightyear (2022)  2022
# 9                   Night Teeth (2021)  2021
# 10              Army of Thieves (2021)  2021
# 11  Venom: Let There Be Carnage (2021)  2021
# 12                     Free Guy (2021)  2021
# 13                      Antlers (2021)  2021
# 14                     Hypnotic (2021)  2021
# 15                           Rust ( 5)     5
# 16                  Hocus Pocus (1993)  1993
# 17                    Halloween (1978)  1978
# 18                   The Batman (2022)  2022
# 19                   Red Notice (2021)  2021
# 20                    Uncharted (2022)  2022
# 21      Spider-Man: No Way Home (2021)  2021
# 22                After We Fell (2021)  2021
# 23                  Black Widow (2021)  2021
# 24         The Forgotten Battle (2020)  2020
#
#                                                 image  \
# 0   https://imdb-api.com/images/original/MV5BN2FjN...
# 1   https://imdb-api.com/images/original/MV5BYTAzY...
# 2   https://imdb-api.com/images/original/MV5BMTExZ...
# 3   https://imdb-api.com/images/original/MV5BYWQ2N...
# 4   https://imdb-api.com/images/original/MV5BM2RmM...
# 5   https://imdb-api.com/images/original/MV5BNmQxZ...
# 6   https://imdb-api.com/images/original/MV5BZjgwZ...
# 7   https://imdb-api.com/images/original/MV5BZGExZ...
# 8   https://imdb-api.com/images/original/MV5BYWM5Z...
# 9   https://imdb-api.com/images/original/MV5BNDhmO...
# 10  https://imdb-api.com/images/original/MV5BZGRlO...
# 11  https://imdb-api.com/images/original/MV5BYTc3Z...
# 12  https://imdb-api.com/images/original/MV5BOTY2N...
# 13  https://imdb-api.com/images/original/MV5BY2UzO...
# 14  https://imdb-api.com/images/original/MV5BYmQxN...
# 15  https://imdb-api.com/images/original/MV5BZjhiY...
# 16  https://imdb-api.com/images/original/MV5BMWUxN...
# 17  https://imdb-api.com/images/original/MV5BNzk1O...
# 18  https://imdb-api.com/images/original/MV5BYTExZ...
# 19  https://imdb-api.com/images/original/MV5BZmRjO...
# 20  https://imdb-api.com/images/original/MV5BOTZjZ...
# 21  https://imdb-api.com/images/original/MV5BNTMxO...
# 22  https://imdb-api.com/images/original/MV5BMTEzN...
# 23  https://imdb-api.com/images/original/MV5BNjRmN...
# 24  https://imdb-api.com/images/original/MV5BM2MzM...
#
#                                                  crew imDbRating  \
# 0   Denis Villeneuve (dir.), Timothée Chalamet, Re...        8.2
# 1   David Lynch (dir.), Kyle MacLachlan, Virginia ...        6.4
# 2       Chloé Zhao (dir.), Gemma Chan, Richard Madden
# 3   Cary Joji Fukunaga (dir.), Daniel Craig, Ana d...        7.5
# 4   David Gordon Green (dir.), Jamie Lee Curtis, J...        5.7
# 5   Wes Anderson (dir.), Benicio Del Toro, Adrien ...        7.5
# 6   Edgar Wright (dir.), Thomasin McKenzie, Anya T...        7.6
# 7        Ridley Scott (dir.), Matt Damon, Adam Driver        7.7
# 8                   Angus MacLane (dir.), Chris Evans
# 9   Adam Randall (dir.), Jorge Lendeborg Jr., Debb...        5.6
# 10  Matthias Schweighöfer (dir.), Matthias Schweig...        6.4
# 11     Andy Serkis (dir.), Tom Hardy, Woody Harrelson        6.3
# 12      Shawn Levy (dir.), Ryan Reynolds, Jodie Comer        7.2
# 13   Scott Cooper (dir.), Keri Russell, Jesse Plemons        6.4
# 14       Matt Angel (dir.), Kate Siegel, Jason O'Mara        5.2
# 15     Joel Souza (dir.), Alec Baldwin, Travis Fimmel
# 16  Kenny Ortega (dir.), Bette Midler, Sarah Jessi...        6.9
# 17  John Carpenter (dir.), Donald Pleasence, Jamie...        7.7
# 18  Matt Reeves (dir.), Amber Sienna, Robert Patti...
# 19  Rawson Marshall Thurber (dir.), Dwayne Johnson...
# 20  Ruben Fleischer (dir.), Tati Gabrielle, Tom Ho...
# 21             Jon Watts (dir.), Zendaya, Tom Holland
# 22  Castille Landon (dir.), Josephine Langford, He...        4.8
# 23  Cate Shortland (dir.), Scarlett Johansson, Flo...        6.8
# 24  Matthijs van Heijningen Jr. (dir.), Gijs Blom,...        7.1
#
#    imDbRatingCount
# 0           257741
# 1           148082
# 2                0
# 3           140906
# 4            49588
# 5            12149
# 6            10011
# 7            18603
# 8                0
# 9             9871
# 10           17239
# 11           51325
# 12          181874
# 13            2757
# 14            6112
# 15               0
# 16          115896
# 17          256365
# 18               0
# 19               0
# 20               0
# 21               0
# 22            5396
# 23          262100
# 24           14658

# %%
r2 = requests.get("https://imdb-api.com/en/API/BoxOfficeAllTime/k_4k2gioan")
r2.status_code
# Out:
# 200

# %%
response2 = r2.json()
response2.keys()

response2['items']
# Out:
# [{'id': 'tt0499549',
#   'rank': '1',
#   'title': 'Avatar',
#   'worldwideLifetimeGross': '$2,847,246,203',
#   'domesticLifetimeGross': '$760,507,625',
#   'domestic': '26.7%',
#   'foreignLifetimeGross': '$2,086,738,578',
#   'foreign': '73.3%',
#   'year': '2009'},
#  {'id': 'tt4154796',
#   'rank': '2',
#   'title': 'Avengers: Endgame',
#   'worldwideLifetimeGross': '$2,797,501,328',
#   'domesticLifetimeGross': '$858,373,000',
#   'domestic': '30.7%',
#   'foreignLifetimeGross': '$1,939,128,328',
#   'foreign': '69.3%',
#   'year': '2019'},
#  {'id': 'tt0120338',
#   'rank': '3',
#   'title': 'Titanic',
#   'worldwideLifetimeGross': '$2,201,647,264',
#   'domesticLifetimeGross': '$659,363,944',
#   'domestic': '30%',
#   'foreignLifetimeGross': '$1,542,283,320',
#   'foreign': '70%',
#   'year': '1997'},
#  {'id': 'tt2488496',
#   'rank': '4',
#   'title': 'Star Wars: Episode VII - The Force Awakens',
#   'worldwideLifetimeGross': '$2,069,521,700',
#   'domesticLifetimeGross': '$936,662,225',
#   'domestic': '45.3%',
#   'foreignLifetimeGross': '$1,132,859,475',
#   'foreign': '54.7%',
#   'year': '2015'},
#  {'id': 'tt4154756',
#   'rank': '5',
#   'title': 'Avengers: Infinity War',
#   'worldwideLifetimeGross': '$2,048,359,754',
#   'domesticLifetimeGross': '$678,815,482',
#   'domestic': '33.1%',
#   'foreignLifetimeGross': '$1,369,544,272',
#   'foreign': '66.9%',
#   'year': '2018'},
#  {'id': 'tt0369610',
#   'rank': '6',
#   'title': 'Jurassic World',
#   'worldwideLifetimeGross': '$1,670,516,444',
#   'domesticLifetimeGross': '$652,385,625',
#   'domestic': '39%',
#   'foreignLifetimeGross': '$1,018,130,819',
#   'foreign': '61%',
#   'year': '2015'},
#  {'id': 'tt6105098',
#   'rank': '7',
#   'title': 'The Lion King',
#   'worldwideLifetimeGross': '$1,667,635,327',
#   'domesticLifetimeGross': '$543,638,043',
#   'domestic': '32.6%',
#   'foreignLifetimeGross': '$1,123,997,284',
#   'foreign': '67.4%',
#   'year': '2019'},
#  {'id': 'tt0848228',
#   'rank': '8',
#   'title': 'The Avengers',
#   'worldwideLifetimeGross': '$1,518,815,515',
#   'domesticLifetimeGross': '$623,357,910',
#   'domestic': '41%',
#   'foreignLifetimeGross': '$895,457,605',
#   'foreign': '59%',
#   'year': '2012'},
#  {'id': 'tt2820852',
#   'rank': '9',
#   'title': 'Furious 7',
#   'worldwideLifetimeGross': '$1,515,341,399',
#   'domesticLifetimeGross': '$353,007,020',
#   'domestic': '23.3%',
#   'foreignLifetimeGross': '$1,162,334,379',
#   'foreign': '76.7%',
#   'year': '2015'},
#  {'id': 'tt4520988',
#   'rank': '10',
#   'title': 'Frozen II',
#   'worldwideLifetimeGross': '$1,450,026,933',
#   'domesticLifetimeGross': '$477,373,578',
#   'domestic': '32.9%',
#   'foreignLifetimeGross': '$972,653,355',
#   'foreign': '67.1%',
#   'year': '2019'},
#  {'id': 'tt2395427',
#   'rank': '11',
#   'title': 'Avengers: Age of Ultron',
#   'worldwideLifetimeGross': '$1,402,809,540',
#   'domesticLifetimeGross': '$459,005,868',
#   'domestic': '32.7%',
#   'foreignLifetimeGross': '$943,803,672',
#   'foreign': '67.3%',
#   'year': '2015'},
#  {'id': 'tt1825683',
#   'rank': '12',
#   'title': 'Black Panther',
#   'worldwideLifetimeGross': '$1,347,597,973',
#   'domesticLifetimeGross': '$700,426,566',
#   'domestic': '52%',
#   'foreignLifetimeGross': '$647,171,407',
#   'foreign': '48%',
#   'year': '2018'},
#  {'id': 'tt1201607',
#   'rank': '13',
#   'title': 'Harry Potter and the Deathly Hallows: Part 2',
#   'worldwideLifetimeGross': '$1,342,321,665',
#   'domesticLifetimeGross': '$381,409,310',
#   'domestic': '28.4%',
#   'foreignLifetimeGross': '$960,912,355',
#   'foreign': '71.6%',
#   'year': '2011'},
#  {'id': 'tt2527336',
#   'rank': '14',
#   'title': 'Star Wars: Episode VIII - The Last Jedi',
#   'worldwideLifetimeGross': '$1,332,698,830',
#   'domesticLifetimeGross': '$620,181,382',
#   'domestic': '46.5%',
#   'foreignLifetimeGross': '$712,517,448',
#   'foreign': '53.5%',
#   'year': '2017'},
#  {'id': 'tt4881806',
#   'rank': '15',
#   'title': 'Jurassic World: Fallen Kingdom',
#   'worldwideLifetimeGross': '$1,310,466,296',
#   'domesticLifetimeGross': '$417,719,760',
#   'domestic': '31.9%',
#   'foreignLifetimeGross': '$892,746,536',
#   'foreign': '68.1%',
#   'year': '2018'},
#  {'id': 'tt2294629',
#   'rank': '16',
#   'title': 'Frozen',
#   'worldwideLifetimeGross': '$1,281,508,100',
#   'domesticLifetimeGross': '$400,953,009',
#   'domestic': '31.3%',
#   'foreignLifetimeGross': '$880,555,091',
#   'foreign': '68.7%',
#   'year': '2013'},
#  {'id': 'tt2771200',
#   'rank': '17',
#   'title': 'Beauty and the Beast',
#   'worldwideLifetimeGross': '$1,273,576,220',
#   'domesticLifetimeGross': '$504,481,165',
#   'domestic': '39.6%',
#   'foreignLifetimeGross': '$769,095,055',
#   'foreign': '60.4%',
#   'year': '2017'},
#  {'id': 'tt3606756',
#   'rank': '18',
#   'title': 'Incredibles 2',
#   'worldwideLifetimeGross': '$1,244,639,527',
#   'domesticLifetimeGross': '$608,581,744',
#   'domestic': '48.9%',
#   'foreignLifetimeGross': '$636,057,783',
#   'foreign': '51.1%',
#   'year': '2018'},
#  {'id': 'tt4630562',
#   'rank': '19',
#   'title': 'The Fate of the Furious',
#   'worldwideLifetimeGross': '$1,236,005,118',
#   'domesticLifetimeGross': '$226,008,385',
#   'domestic': '18.3%',
#   'foreignLifetimeGross': '$1,009,996,733',
#   'foreign': '81.7%',
#   'year': '2017'},
#  {'id': 'tt1300854',
#   'rank': '20',
#   'title': 'Iron Man 3',
#   'worldwideLifetimeGross': '$1,214,811,252',
#   'domesticLifetimeGross': '$409,013,994',
#   'domestic': '33.7%',
#   'foreignLifetimeGross': '$805,797,258',
#   'foreign': '66.3%',
#   'year': '2013'},
#  {'id': 'tt2293640',
#   'rank': '21',
#   'title': 'Minions',
#   'worldwideLifetimeGross': '$1,159,444,662',
#   'domesticLifetimeGross': '$336,045,770',
#   'domestic': '29%',
#   'foreignLifetimeGross': '$823,398,892',
#   'foreign': '71%',
#   'year': '2015'},
#  {'id': 'tt3498820',
#   'rank': '22',
#   'title': 'Captain America: Civil War',
#   'worldwideLifetimeGross': '$1,153,337,496',
#   'domesticLifetimeGross': '$408,084,349',
#   'domestic': '35.4%',
#   'foreignLifetimeGross': '$745,253,147',
#   'foreign': '64.6%',
#   'year': '2016'},
#  {'id': 'tt1477834',
#   'rank': '23',
#   'title': 'Aquaman',
#   'worldwideLifetimeGross': '$1,148,485,886',
#   'domesticLifetimeGross': '$335,061,807',
#   'domestic': '29.2%',
#   'foreignLifetimeGross': '$813,424,079',
#   'foreign': '70.8%',
#   'year': '2018'},
#  {'id': 'tt0167260',
#   'rank': '24',
#   'title': 'The Lord of the Rings: The Return of the King',
#   'worldwideLifetimeGross': '$1,146,030,912',
#   'domesticLifetimeGross': '$377,845,905',
#   'domestic': '33%',
#   'foreignLifetimeGross': '$768,185,007',
#   'foreign': '67%',
#   'year': '2003'},
#  {'id': 'tt6320628',
#   'rank': '25',
#   'title': 'Spider-Man: Far from Home',
#   'worldwideLifetimeGross': '$1,131,927,996',
#   'domesticLifetimeGross': '$390,532,085',
#   'domestic': '34.5%',
#   'foreignLifetimeGross': '$741,395,911',
#   'foreign': '65.5%',
#   'year': '2019'},
#  {'id': 'tt4154664',
#   'rank': '26',
#   'title': 'Captain Marvel',
#   'worldwideLifetimeGross': '$1,128,462,972',
#   'domesticLifetimeGross': '$426,829,839',
#   'domestic': '37.8%',
#   'foreignLifetimeGross': '$701,633,133',
#   'foreign': '62.2%',
#   'year': '2019'},
#  {'id': 'tt1399103',
#   'rank': '27',
#   'title': 'Transformers: Dark of the Moon',
#   'worldwideLifetimeGross': '$1,123,794,079',
#   'domesticLifetimeGross': '$352,390,543',
#   'domestic': '31.4%',
#   'foreignLifetimeGross': '$771,403,536',
#   'foreign': '68.6%',
#   'year': '2011'},
#  {'id': 'tt1074638',
#   'rank': '28',
#   'title': 'Skyfall',
#   'worldwideLifetimeGross': '$1,108,569,499',
#   'domesticLifetimeGross': '$304,360,277',
#   'domestic': '27.5%',
#   'foreignLifetimeGross': '$804,209,222',
#   'foreign': '72.5%',
#   'year': '2012'},
#  {'id': 'tt2109248',
#   'rank': '29',
#   'title': 'Transformers: Age of Extinction',
#   'worldwideLifetimeGross': '$1,104,054,072',
#   'domesticLifetimeGross': '$245,439,076',
#   'domestic': '22.2%',
#   'foreignLifetimeGross': '$858,614,996',
#   'foreign': '77.8%',
#   'year': '2014'},
#  {'id': 'tt1345836',
#   'rank': '30',
#   'title': 'The Dark Knight Rises',
#   'worldwideLifetimeGross': '$1,081,142,612',
#   'domesticLifetimeGross': '$448,139,099',
#   'domestic': '41.4%',
#   'foreignLifetimeGross': '$633,003,513',
#   'foreign': '58.6%',
#   'year': '2012'},
#  {'id': 'tt2527338',
#   'rank': '31',
#   'title': 'Star Wars: Episode IX - The Rise of Skywalker',
#   'worldwideLifetimeGross': '$1,078,232,589',
#   'domesticLifetimeGross': '$515,202,542',
#   'domestic': '47.8%',
#   'foreignLifetimeGross': '$563,030,047',
#   'foreign': '52.2%',
#   'year': '2019'},
#  {'id': 'tt7286456',
#   'rank': '32',
#   'title': 'Joker',
#   'worldwideLifetimeGross': '$1,074,419,384',
#   'domesticLifetimeGross': '$335,451,311',
#   'domestic': '31.2%',
#   'foreignLifetimeGross': '$738,968,073',
#   'foreign': '68.8%',
#   'year': '2019'},
#  {'id': 'tt1979376',
#   'rank': '33',
#   'title': 'Toy Story 4',
#   'worldwideLifetimeGross': '$1,073,394,593',
#   'domesticLifetimeGross': '$434,038,008',
#   'domestic': '40.4%',
#   'foreignLifetimeGross': '$639,356,585',
#   'foreign': '59.6%',
#   'year': '2019'},
#  {'id': 'tt0435761',
#   'rank': '34',
#   'title': 'Toy Story 3',
#   'worldwideLifetimeGross': '$1,066,970,811',
#   'domesticLifetimeGross': '$415,004,880',
#   'domestic': '38.9%',
#   'foreignLifetimeGross': '$651,965,931',
#   'foreign': '61.1%',
#   'year': '2010'},
#  {'id': 'tt0383574',
#   'rank': '35',
#   'title': "Pirates of the Caribbean: Dead Man's Chest",
#   'worldwideLifetimeGross': '$1,066,179,747',
#   'domesticLifetimeGross': '$423,315,812',
#   'domestic': '39.7%',
#   'foreignLifetimeGross': '$642,863,935',
#   'foreign': '60.3%',
#   'year': '2006'},
#  {'id': 'tt0110357',
#   'rank': '36',
#   'title': 'The Lion King',
#   'worldwideLifetimeGross': '$1,063,611,805',
#   'domesticLifetimeGross': '$422,783,777',
#   'domestic': '39.8%',
#   'foreignLifetimeGross': '$640,828,028',
#   'foreign': '60.2%',
#   'year': '1994'},
#  {'id': 'tt3748528',
#   'rank': '37',
#   'title': 'Rogue One: A Star Wars Story',
#   'worldwideLifetimeGross': '$1,056,057,720',
#   'domesticLifetimeGross': '$532,177,324',
#   'domestic': '50.4%',
#   'foreignLifetimeGross': '$523,880,396',
#   'foreign': '49.6%',
#   'year': '2016'},
#  {'id': 'tt6139732',
#   'rank': '38',
#   'title': 'Aladdin',
#   'worldwideLifetimeGross': '$1,050,693,953',
#   'domesticLifetimeGross': '$355,559,216',
#   'domestic': '33.8%',
#   'foreignLifetimeGross': '$695,134,737',
#   'foreign': '66.2%',
#   'year': '2019'},
#  {'id': 'tt1298650',
#   'rank': '39',
#   'title': 'Pirates of the Caribbean: On Stranger Tides',
#   'worldwideLifetimeGross': '$1,045,713,802',
#   'domesticLifetimeGross': '$241,071,802',
#   'domestic': '23%',
#   'foreignLifetimeGross': '$804,642,000',
#   'foreign': '77%',
#   'year': '2011'},
#  {'id': 'tt3469046',
#   'rank': '40',
#   'title': 'Despicable Me 3',
#   'worldwideLifetimeGross': '$1,034,800,131',
#   'domesticLifetimeGross': '$264,624,300',
#   'domestic': '25.6%',
#   'foreignLifetimeGross': '$770,175,831',
#   'foreign': '74.4%',
#   'year': '2017'},
#  {'id': 'tt0107290',
#   'rank': '41',
#   'title': 'Jurassic Park',
#   'worldwideLifetimeGross': '$1,033,928,303',
#   'domesticLifetimeGross': '$404,214,720',
#   'domestic': '39.1%',
#   'foreignLifetimeGross': '$629,713,583',
#   'foreign': '60.9%',
#   'year': '1993'},
#  {'id': 'tt2277860',
#   'rank': '42',
#   'title': 'Finding Dory',
#   'worldwideLifetimeGross': '$1,028,570,942',
#   'domesticLifetimeGross': '$486,295,561',
#   'domestic': '47.3%',
#   'foreignLifetimeGross': '$542,275,381',
#   'foreign': '52.7%',
#   'year': '2016'},
#  {'id': 'tt0120915',
#   'rank': '43',
#   'title': 'Star Wars: Episode I - The Phantom Menace',
#   'worldwideLifetimeGross': '$1,027,082,707',
#   'domesticLifetimeGross': '$474,544,677',
#   'domestic': '46.2%',
#   'foreignLifetimeGross': '$552,538,030',
#   'foreign': '53.8%',
#   'year': '1999'},
#  {'id': 'tt1014759',
#   'rank': '44',
#   'title': 'Alice in Wonderland',
#   'worldwideLifetimeGross': '$1,025,468,216',
#   'domesticLifetimeGross': '$334,191,110',
#   'domestic': '32.6%',
#   'foreignLifetimeGross': '$691,277,106',
#   'foreign': '67.4%',
#   'year': '2010'},
#  {'id': 'tt2948356',
#   'rank': '45',
#   'title': 'Zootopia',
#   'worldwideLifetimeGross': '$1,024,121,104',
#   'domesticLifetimeGross': '$341,268,248',
#   'domestic': '33.3%',
#   'foreignLifetimeGross': '$682,852,856',
#   'foreign': '66.7%',
#   'year': '2016'},
#  {'id': 'tt0903624',
#   'rank': '46',
#   'title': 'The Hobbit: An Unexpected Journey',
#   'worldwideLifetimeGross': '$1,017,003,568',
#   'domesticLifetimeGross': '$303,003,568',
#   'domestic': '29.8%',
#   'foreignLifetimeGross': '$714,000,000',
#   'foreign': '70.2%',
#   'year': '2012'},
#  {'id': 'tt0241527',
#   'rank': '47',
#   'title': "Harry Potter and the Sorcerer's Stone",
#   'worldwideLifetimeGross': '$1,009,472,460',
#   'domesticLifetimeGross': '$318,087,620',
#   'domestic': '31.5%',
#   'foreignLifetimeGross': '$691,384,840',
#   'foreign': '68.5%',
#   'year': '2001'},
#  {'id': 'tt0468569',
#   'rank': '48',
#   'title': 'The Dark Knight',
#   'worldwideLifetimeGross': '$1,005,973,645',
#   'domesticLifetimeGross': '$534,858,444',
#   'domestic': '53.2%',
#   'foreignLifetimeGross': '$471,115,201',
#   'foreign': '46.8%',
#   'year': '2008'},
#  {'id': 'tt0926084',
#   'rank': '49',
#   'title': 'Harry Potter and the Deathly Hallows: Part 1',
#   'worldwideLifetimeGross': '$977,043,483',
#   'domesticLifetimeGross': '$296,347,721',
#   'domestic': '30.3%',
#   'foreignLifetimeGross': '$680,695,762',
#   'foreign': '69.7%',
#   'year': '2010'},
#  {'id': 'tt1690953',
#   'rank': '50',
#   'title': 'Despicable Me 2',
#   'worldwideLifetimeGross': '$970,766,005',
#   'domesticLifetimeGross': '$368,065,385',
#   'domestic': '37.9%',
#   'foreignLifetimeGross': '$602,700,620',
#   'foreign': '62.1%',
#   'year': '2013'},
#  {'id': 'tt3040964',
#   'rank': '51',
#   'title': 'The Jungle Book',
#   'worldwideLifetimeGross': '$966,554,929',
#   'domesticLifetimeGross': '$364,001,123',
#   'domestic': '37.7%',
#   'foreignLifetimeGross': '$602,553,806',
#   'foreign': '62.3%',
#   'year': '2016'},
#  {'id': 'tt2283362',
#   'rank': '52',
#   'title': 'Jumanji: Welcome to the Jungle',
#   'worldwideLifetimeGross': '$962,542,945',
#   'domesticLifetimeGross': '$404,540,171',
#   'domestic': '42%',
#   'foreignLifetimeGross': '$558,002,774',
#   'foreign': '58%',
#   'year': '2017'},
#  {'id': 'tt2310332',
#   'rank': '53',
#   'title': 'The Hobbit: The Battle of the Five Armies',
#   'worldwideLifetimeGross': '$962,182,865',
#   'domesticLifetimeGross': '$255,119,788',
#   'domestic': '26.5%',
#   'foreignLifetimeGross': '$707,063,077',
#   'foreign': '73.5%',
#   'year': '2014'},
#  {'id': 'tt0449088',
#   'rank': '54',
#   'title': "Pirates of the Caribbean: At World's End",
#   'worldwideLifetimeGross': '$960,996,492',
#   'domesticLifetimeGross': '$309,420,425',
#   'domestic': '32.2%',
#   'foreignLifetimeGross': '$651,576,067',
#   'foreign': '67.8%',
#   'year': '2007'},
#  {'id': 'tt1170358',
#   'rank': '55',
#   'title': 'The Hobbit: The Desolation of Smaug',
#   'worldwideLifetimeGross': '$959,007,513',
#   'domesticLifetimeGross': '$258,366,855',
#   'domestic': '26.9%',
#   'foreignLifetimeGross': '$700,640,658',
#   'foreign': '73.1%',
#   'year': '2013'},
#  {'id': 'tt0167261',
#   'rank': '56',
#   'title': 'The Lord of the Rings: The Two Towers',
#   'worldwideLifetimeGross': '$947,495,095',
#   'domesticLifetimeGross': '$342,551,365',
#   'domestic': '36.2%',
#   'foreignLifetimeGross': '$604,943,730',
#   'foreign': '63.8%',
#   'year': '2002'},
#  {'id': 'tt0373889',
#   'rank': '57',
#   'title': 'Harry Potter and the Order of the Phoenix',
#   'worldwideLifetimeGross': '$942,172,396',
#   'domesticLifetimeGross': '$292,353,413',
#   'domestic': '31%',
#   'foreignLifetimeGross': '$649,818,983',
#   'foreign': '69%',
#   'year': '2007'},
#  {'id': 'tt0266543',
#   'rank': '58',
#   'title': 'Finding Nemo',
#   'worldwideLifetimeGross': '$940,352,645',
#   'domesticLifetimeGross': '$380,843,261',
#   'domestic': '40.5%',
#   'foreignLifetimeGross': '$559,509,384',
#   'foreign': '59.5%',
#   'year': '2003'},
#  {'id': 'tt0417741',
#   'rank': '59',
#   'title': 'Harry Potter and the Half-Blood Prince',
#   'worldwideLifetimeGross': '$934,454,096',
#   'domesticLifetimeGross': '$302,305,431',
#   'domestic': '32.4%',
#   'foreignLifetimeGross': '$632,148,665',
#   'foreign': '67.6%',
#   'year': '2009'},
#  {'id': 'tt0298148',
#   'rank': '60',
#   'title': 'Shrek 2',
#   'worldwideLifetimeGross': '$928,760,770',
#   'domesticLifetimeGross': '$441,226,247',
#   'domestic': '47.5%',
#   'foreignLifetimeGross': '$487,534,523',
#   'foreign': '52.5%',
#   'year': '2004'},
#  {'id': 'tt1727824',
#   'rank': '61',
#   'title': 'Bohemian Rhapsody',
#   'worldwideLifetimeGross': '$911,100,727',
#   'domesticLifetimeGross': '$216,668,042',
#   'domestic': '23.8%',
#   'foreignLifetimeGross': '$694,432,685',
#   'foreign': '76.2%',
#   'year': '2018'},
#  {'id': 'tt0120737',
#   'rank': '62',
#   'title': 'The Lord of the Rings: The Fellowship of the Ring',
#   'worldwideLifetimeGross': '$897,690,072',
#   'domesticLifetimeGross': '$315,710,750',
#   'domestic': '35.2%',
#   'foreignLifetimeGross': '$581,979,322',
#   'foreign': '64.8%',
#   'year': '2001'},
#  {'id': 'tt0330373',
#   'rank': '63',
#   'title': 'Harry Potter and the Goblet of Fire',
#   'worldwideLifetimeGross': '$896,678,241',
#   'domesticLifetimeGross': '$290,417,905',
#   'domestic': '32.4%',
#   'foreignLifetimeGross': '$606,260,336',
#   'foreign': '67.6%',
#   'year': '2005'},
#  {'id': 'tt0413300',
#   'rank': '64',
#   'title': 'Spider-Man 3',
#   'worldwideLifetimeGross': '$894,983,373',
#   'domesticLifetimeGross': '$336,530,303',
#   'domestic': '37.6%',
#   'foreignLifetimeGross': '$558,453,070',
#   'foreign': '62.4%',
#   'year': '2007'},
#  {'id': 'tt1080016',
#   'rank': '65',
#   'title': 'Ice Age: Dawn of the Dinosaurs',
#   'worldwideLifetimeGross': '$886,686,817',
#   'domesticLifetimeGross': '$196,573,705',
#   'domestic': '22.2%',
#   'foreignLifetimeGross': '$690,113,112',
#   'foreign': '77.8%',
#   'year': '2009'},
#  {'id': 'tt2379713',
#   'rank': '66',
#   'title': 'Spectre',
#   'worldwideLifetimeGross': '$880,681,519',
#   'domesticLifetimeGross': '$200,074,609',
#   'domestic': '22.7%',
#   'foreignLifetimeGross': '$680,606,910',
#   'foreign': '77.3%',
#   'year': '2015'},
#  {'id': 'tt2250912',
#   'rank': '67',
#   'title': 'Spider-Man: Homecoming',
#   'worldwideLifetimeGross': '$880,166,924',
#   'domesticLifetimeGross': '$334,201,140',
#   'domestic': '38%',
#   'foreignLifetimeGross': '$545,965,784',
#   'foreign': '62%',
#   'year': '2017'},
#  {'id': 'tt0295297',
#   'rank': '68',
#   'title': 'Harry Potter and the Chamber of Secrets',
#   'worldwideLifetimeGross': '$879,602,366',
#   'domesticLifetimeGross': '$262,450,136',
#   'domestic': '29.8%',
#   'foreignLifetimeGross': '$617,152,230',
#   'foreign': '70.2%',
#   'year': '2002'},
#  {'id': 'tt1667889',
#   'rank': '69',
#   'title': 'Ice Age: Continental Drift',
#   'worldwideLifetimeGross': '$877,244,782',
#   'domesticLifetimeGross': '$161,321,843',
#   'domestic': '18.4%',
#   'foreignLifetimeGross': '$715,922,939',
#   'foreign': '81.6%',
#   'year': '2012'},
#  {'id': 'tt2709768',
#   'rank': '70',
#   'title': 'The Secret Life of Pets',
#   'worldwideLifetimeGross': '$875,458,631',
#   'domesticLifetimeGross': '$368,384,330',
#   'domestic': '42.1%',
#   'foreignLifetimeGross': '$507,074,301',
#   'foreign': '57.9%',
#   'year': '2016'},
#  {'id': 'tt2975590',
#   'rank': '71',
#   'title': 'Batman v Superman: Dawn of Justice',
#   'worldwideLifetimeGross': '$873,637,528',
#   'domesticLifetimeGross': '$330,360,194',
#   'domestic': '37.8%',
#   'foreignLifetimeGross': '$543,277,334',
#   'foreign': '62.2%',
#   'year': '2016'},
#  {'id': 'tt7131870',
#   'rank': '72',
#   'title': 'Wolf Warrior 2',
#   'worldwideLifetimeGross': '$870,325,439',
#   'domesticLifetimeGross': '$2,721,100',
#   'domestic': '0.3%',
#   'foreignLifetimeGross': '$867,604,339',
#   'foreign': '99.7%',
#   'year': '2017'},
#  {'id': 'tt0121766',
#   'rank': '73',
#   'title': 'Star Wars: Episode III - Revenge of the Sith',
#   'worldwideLifetimeGross': '$868,390,560',
#   'domesticLifetimeGross': '$380,270,577',
#   'domestic': '43.8%',
#   'foreignLifetimeGross': '$488,119,983',
#   'foreign': '56.2%',
#   'year': '2005'},
#  {'id': 'tt1951264',
#   'rank': '74',
#   'title': 'The Hunger Games: Catching Fire',
#   'worldwideLifetimeGross': '$865,011,746',
#   'domesticLifetimeGross': '$424,668,047',
#   'domestic': '49.1%',
#   'foreignLifetimeGross': '$440,343,699',
#   'foreign': '50.9%',
#   'year': '2013'},
#  {'id': 'tt3896198',
#   'rank': '75',
#   'title': 'Guardians of the Galaxy Vol. 2',
#   'worldwideLifetimeGross': '$863,756,051',
#   'domesticLifetimeGross': '$389,813,101',
#   'domestic': '45.1%',
#   'foreignLifetimeGross': '$473,942,950',
#   'foreign': '54.9%',
#   'year': '2017'},
#  {'id': 'tt13462900',
#   'rank': '76',
#   'title': 'The Battle at Lake Changjin',
#   'worldwideLifetimeGross': '$859,000,000',
#   'domesticLifetimeGross': '-',
#   'domestic': '-',
#   'foreignLifetimeGross': '$859,000,000',
#   'foreign': '100%',
#   'year': '2021'},
#  {'id': 'tt2096673',
#   'rank': '77',
#   'title': 'Inside Out',
#   'worldwideLifetimeGross': '$858,848,019',
#   'domesticLifetimeGross': '$356,921,711',
#   'domestic': '41.6%',
#   'foreignLifetimeGross': '$501,926,308',
#   'foreign': '58.4%',
#   'year': '2015'},
#  {'id': 'tt1270797',
#   'rank': '78',
#   'title': 'Venom',
#   'worldwideLifetimeGross': '$856,085,151',
#   'domesticLifetimeGross': '$213,515,506',
#   'domestic': '24.9%',
#   'foreignLifetimeGross': '$642,569,645',
#   'foreign': '75.1%',
#   'year': '2018'},
#  {'id': 'tt3501632',
#   'rank': '79',
#   'title': 'Thor: Ragnarok',
#   'worldwideLifetimeGross': '$853,983,911',
#   'domesticLifetimeGross': '$315,058,289',
#   'domestic': '36.9%',
#   'foreignLifetimeGross': '$538,925,622',
#   'foreign': '63.1%',
#   'year': '2017'},
#  {'id': 'tt1375666',
#   'rank': '80',
#   'title': 'Inception',
#   'worldwideLifetimeGross': '$836,836,967',
#   'domesticLifetimeGross': '$292,576,195',
#   'domestic': '35%',
#   'foreignLifetimeGross': '$544,260,772',
#   'foreign': '65%',
#   'year': '2010'},
#  {'id': 'tt1055369',
#   'rank': '81',
#   'title': 'Transformers: Revenge of the Fallen',
#   'worldwideLifetimeGross': '$836,303,693',
#   'domesticLifetimeGross': '$402,111,870',
#   'domestic': '48.1%',
#   'foreignLifetimeGross': '$434,191,823',
#   'foreign': '51.9%',
#   'year': '2009'},
#  {'id': 'tt1673434',
#   'rank': '82',
#   'title': 'The Twilight Saga: Breaking Dawn - Part 2',
#   'worldwideLifetimeGross': '$829,747,654',
#   'domesticLifetimeGross': '$292,324,737',
#   'domestic': '35.2%',
#   'foreignLifetimeGross': '$537,422,917',
#   'foreign': '64.8%',
#   'year': '2012'},
#  {'id': 'tt0145487',
#   'rank': '83',
#   'title': 'Spider-Man',
#   'worldwideLifetimeGross': '$825,025,036',
#   'domesticLifetimeGross': '$407,022,860',
#   'domestic': '49.3%',
#   'foreignLifetimeGross': '$418,002,176',
#   'foreign': '50.7%',
#   'year': '2002'},
#  {'id': 'tt0451279',
#   'rank': '84',
#   'title': 'Wonder Woman',
#   'worldwideLifetimeGross': '$822,824,522',
#   'domesticLifetimeGross': '$412,815,408',
#   'domestic': '50.2%',
#   'foreignLifetimeGross': '$410,009,114',
#   'foreign': '49.8%',
#   'year': '2017'},
#  {'id': 'tt13364790',
#   'rank': '85',
#   'title': 'Hi, Mom',
#   'worldwideLifetimeGross': '$822,009,764',
#   'domesticLifetimeGross': '-',
#   'domestic': '-',
#   'foreignLifetimeGross': '$822,009,764',
#   'foreign': '100%',
#   'year': '2021'},
#  {'id': 'tt0116629',
#   'rank': '86',
#   'title': 'Independence Day',
#   'worldwideLifetimeGross': '$817,400,891',
#   'domesticLifetimeGross': '$306,169,268',
#   'domestic': '37.5%',
#   'foreignLifetimeGross': '$511,231,623',
#   'foreign': '62.5%',
#   'year': '1996'},
#  {'id': 'tt3183660',
#   'rank': '87',
#   'title': 'Fantastic Beasts and Where to Find Them',
#   'worldwideLifetimeGross': '$814,044,001',
#   'domesticLifetimeGross': '$234,037,575',
#   'domestic': '28.8%',
#   'foreignLifetimeGross': '$580,006,426',
#   'foreign': '71.2%',
#   'year': '2016'},
#  {'id': 'tt0413267',
#   'rank': '88',
#   'title': 'Shrek the Third',
#   'worldwideLifetimeGross': '$813,367,380',
#   'domesticLifetimeGross': '$322,719,944',
#   'domestic': '39.7%',
#   'foreignLifetimeGross': '$490,647,436',
#   'foreign': '60.3%',
#   'year': '2007'},
#  {'id': 'tt2380307',
#   'rank': '89',
#   'title': 'Coco',
#   'worldwideLifetimeGross': '$807,817,888',
#   'domesticLifetimeGross': '$210,460,015',
#   'domestic': '26%',
#   'foreignLifetimeGross': '$597,357,873',
#   'foreign': '74%',
#   'year': '2017'},
#  {'id': 'tt7975244',
#   'rank': '90',
#   'title': 'Jumanji: The Next Level',
#   'worldwideLifetimeGross': '$800,059,707',
#   'domesticLifetimeGross': '$320,314,960',
#   'domestic': '40%',
#   'foreignLifetimeGross': '$479,744,747',
#   'foreign': '60%',
#   'year': '2019'},
#  {'id': 'tt0304141',
#   'rank': '91',
#   'title': 'Harry Potter and the Prisoner of Azkaban',
#   'worldwideLifetimeGross': '$797,361,618',
#   'domesticLifetimeGross': '$249,975,996',
#   'domestic': '31.4%',
#   'foreignLifetimeGross': '$547,385,622',
#   'foreign': '68.6%',
#   'year': '2004'},
#  {'id': 'tt1790809',
#   'rank': '92',
#   'title': 'Pirates of the Caribbean: Dead Men Tell No Tales',
#   'worldwideLifetimeGross': '$794,881,442',
#   'domesticLifetimeGross': '$172,558,876',
#   'domestic': '21.7%',
#   'foreignLifetimeGross': '$622,322,566',
#   'foreign': '78.3%',
#   'year': '2017'},
#  {'id': 'tt0083866',
#   'rank': '93',
#   'title': 'E.T. the Extra-Terrestrial',
#   'worldwideLifetimeGross': '$792,910,554',
#   'domesticLifetimeGross': '$435,110,554',
#   'domestic': '54.9%',
#   'foreignLifetimeGross': '$357,800,000',
#   'foreign': '45.1%',
#   'year': '1982'},
#  {'id': 'tt4912910',
#   'rank': '94',
#   'title': 'Mission: Impossible - Fallout',
#   'worldwideLifetimeGross': '$791,657,398',
#   'domesticLifetimeGross': '$220,159,104',
#   'domestic': '27.8%',
#   'foreignLifetimeGross': '$571,498,294',
#   'foreign': '72.2%',
#   'year': '2018'},
#  {'id': 'tt1190080',
#   'rank': '95',
#   'title': '2012',
#   'worldwideLifetimeGross': '$791,217,826',
#   'domesticLifetimeGross': '$166,112,167',
#   'domestic': '21%',
#   'foreignLifetimeGross': '$625,105,659',
#   'foreign': '79%',
#   'year': '2009'},
#  {'id': 'tt0367882',
#   'rank': '96',
#   'title': 'Indiana Jones and the Kingdom of the Crystal Skull',
#   'worldwideLifetimeGross': '$790,653,942',
#   'domesticLifetimeGross': '$317,101,119',
#   'domestic': '40.1%',
#   'foreignLifetimeGross': '$473,552,823',
#   'foreign': '59.9%',
#   'year': '2008'},
#  {'id': 'tt0316654',
#   'rank': '97',
#   'title': 'Spider-Man 2',
#   'worldwideLifetimeGross': '$788,976,453',
#   'domesticLifetimeGross': '$373,585,825',
#   'domestic': '47.4%',
#   'foreignLifetimeGross': '$415,390,628',
#   'foreign': '52.6%',
#   'year': '2004'},
#  {'id': 'tt1905041',
#   'rank': '98',
#   'title': 'Fast & Furious 6',
#   'worldwideLifetimeGross': '$788,680,968',
#   'domesticLifetimeGross': '$238,679,850',
#   'domestic': '30.3%',
#   'foreignLifetimeGross': '$550,001,118',
#   'foreign': '69.7%',
#   'year': '2013'},
#  {'id': 'tt5463162',
#   'rank': '99',
#   'title': 'Deadpool 2',
#   'worldwideLifetimeGross': '$786,470,484',
#   'domesticLifetimeGross': '$324,591,735',
#   'domestic': '41.3%',
#   'foreignLifetimeGross': '$461,878,749',
#   'foreign': '58.7%',
#   'year': '2018'},
#  {'id': 'tt1431045',
#   'rank': '100',
#   'title': 'Deadpool',
#   'worldwideLifetimeGross': '$782,836,791',
#   'domesticLifetimeGross': '$363,070,709',
#   'domestic': '46.4%',
#   'foreignLifetimeGross': '$419,766,082',
#   'foreign': '53.6%',
#   'year': '2016'},
#  {'id': 'tt0076759',
#   'rank': '101',
#   'title': 'Star Wars: Episode IV - A New Hope',
#   'worldwideLifetimeGross': '$775,398,007',
#   'domesticLifetimeGross': '$460,998,507',
#   'domestic': '59.4%',
#   'foreignLifetimeGross': '$314,399,500',
#   'foreign': '40.6%',
#   'year': '1977'},
#  {'id': 'tt2015381',
#   'rank': '102',
#   'title': 'Guardians of the Galaxy',
#   'worldwideLifetimeGross': '$773,350,147',
#   'domesticLifetimeGross': '$333,718,600',
#   'domestic': '43.2%',
#   'foreignLifetimeGross': '$439,631,547',
#   'foreign': '56.8%',
#   'year': '2014'},
#  {'id': 'tt0382625',
#   'rank': '103',
#   'title': 'The Da Vinci Code',
#   'worldwideLifetimeGross': '$760,006,945',
#   'domesticLifetimeGross': '$217,536,138',
#   'domestic': '28.6%',
#   'foreignLifetimeGross': '$542,470,807',
#   'foreign': '71.4%',
#   'year': '2006'},
#  {'id': 'tt6806448',
#   'rank': '104',
#   'title': 'Fast & Furious Presents: Hobbs & Shaw',
#   'worldwideLifetimeGross': '$759,056,935',
#   'domesticLifetimeGross': '$173,956,935',
#   'domestic': '22.9%',
#   'foreignLifetimeGross': '$585,100,000',
#   'foreign': '77.1%',
#   'year': '2019'},
#  {'id': 'tt1587310',
#   'rank': '105',
#   'title': 'Maleficent',
#   'worldwideLifetimeGross': '$758,411,779',
#   'domesticLifetimeGross': '$241,410,378',
#   'domestic': '31.8%',
#   'foreignLifetimeGross': '$517,001,401',
#   'foreign': '68.2%',
#   'year': '2014'},
#  {'id': 'tt0948470',
#   'rank': '106',
#   'title': 'The Amazing Spider-Man',
#   'worldwideLifetimeGross': '$757,930,663',
#   'domesticLifetimeGross': '$262,030,663',
#   'domestic': '34.6%',
#   'foreignLifetimeGross': '$495,900,000',
#   'foreign': '65.4%',
#   'year': '2012'},
#  {'id': 'tt1951265',
#   'rank': '107',
#   'title': 'The Hunger Games: Mockingjay - Part 1',
#   'worldwideLifetimeGross': '$755,356,711',
#   'domesticLifetimeGross': '$337,135,885',
#   'domestic': '44.6%',
#   'foreignLifetimeGross': '$418,220,826',
#   'foreign': '55.4%',
#   'year': '2014'},
#  {'id': 'tt0892791',
#   'rank': '108',
#   'title': 'Shrek Forever After',
#   'worldwideLifetimeGross': '$752,600,867',
#   'domesticLifetimeGross': '$238,736,787',
#   'domestic': '31.7%',
#   'foreignLifetimeGross': '$513,864,080',
#   'foreign': '68.3%',
#   'year': '2010'},
#  {'id': 'tt1277953',
#   'rank': '109',
#   'title': "Madagascar 3: Europe's Most Wanted",
#   'worldwideLifetimeGross': '$746,921,274',
#   'domesticLifetimeGross': '$216,391,482',
#   'domestic': '29%',
#   'foreignLifetimeGross': '$530,529,792',
#   'foreign': '71%',
#   'year': '2012'},
#  {'id': 'tt1386697',
#   'rank': '110',
#   'title': 'Suicide Squad',
#   'worldwideLifetimeGross': '$746,846,894',
#   'domesticLifetimeGross': '$325,100,054',
#   'domestic': '43.5%',
#   'foreignLifetimeGross': '$421,746,840',
#   'foreign': '56.5%',
#   'year': '2016'},
#  {'id': 'tt1877832',
#   'rank': '111',
#   'title': 'X-Men: Days of Future Past',
#   'worldwideLifetimeGross': '$746,045,700',
#   'domesticLifetimeGross': '$233,921,534',
#   'domestic': '31.4%',
#   'foreignLifetimeGross': '$512,124,166',
#   'foreign': '68.6%',
#   'year': '2014'},
#  {'id': 'tt0363771',
#   'rank': '112',
#   'title': 'The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',
#   'worldwideLifetimeGross': '$745,013,115',
#   'domesticLifetimeGross': '$291,710,957',
#   'domestic': '39.2%',
#   'foreignLifetimeGross': '$453,302,158',
#   'foreign': '60.8%',
#   'year': '2005'},
#  {'id': 'tt1453405',
#   'rank': '113',
#   'title': 'Monsters University',
#   'worldwideLifetimeGross': '$743,559,645',
#   'domesticLifetimeGross': '$268,492,764',
#   'domestic': '36.1%',
#   'foreignLifetimeGross': '$475,066,881',
#   'foreign': '63.9%',
#   'year': '2013'},
#  {'id': 'tt0234215',
#   'rank': '114',
#   'title': 'The Matrix Reloaded',
#   'worldwideLifetimeGross': '$741,847,937',
#   'domesticLifetimeGross': '$281,576,461',
#   'domestic': '38%',
#   'foreignLifetimeGross': '$460,271,476',
#   'foreign': '62%',
#   'year': '2003'},
#  {'id': 'tt1049413',
#   'rank': '115',
#   'title': 'Up',
#   'worldwideLifetimeGross': '$735,099,102',
#   'domesticLifetimeGross': '$293,004,164',
#   'domestic': '39.9%',
#   'foreignLifetimeGross': '$442,094,938',
#   'foreign': '60.1%',
#   'year': '2009'},
#  {'id': 'tt10627720',
#   'rank': '116',
#   'title': 'Ne Zha',
#   'worldwideLifetimeGross': '$726,264,074',
#   'domesticLifetimeGross': '$3,695,533',
#   'domestic': '0.5%',
#   'foreignLifetimeGross': '$722,568,541',
#   'foreign': '99.5%',
#   'year': '2019'},
#  {'id': 'tt1454468',
#   'rank': '117',
#   'title': 'Gravity',
#   'worldwideLifetimeGross': '$723,192,705',
#   'domesticLifetimeGross': '$274,092,705',
#   'domestic': '37.9%',
#   'foreignLifetimeGross': '$449,100,000',
#   'foreign': '62.1%',
#   'year': '2013'},
#  {'id': 'tt5433138',
#   'rank': '118',
#   'title': 'F9: The Fast Saga',
#   'worldwideLifetimeGross': '$721,077,945',
#   'domesticLifetimeGross': '$173,005,945',
#   'domestic': '24%',
#   'foreignLifetimeGross': '$548,072,000',
#   'foreign': '76%',
#   'year': '2021'},
#  {'id': 'tt1843866',
#   'rank': '119',
#   'title': 'Captain America: The Winter Soldier',
#   'worldwideLifetimeGross': '$714,421,503',
#   'domesticLifetimeGross': '$259,766,572',
#   'domestic': '36.4%',
#   'foreignLifetimeGross': '$454,654,931',
#   'foreign': '63.6%',
#   'year': '2014'},
#  {'id': 'tt1324999',
#   'rank': '120',
#   'title': 'The Twilight Saga: Breaking Dawn - Part 1',
#   'worldwideLifetimeGross': '$712,205,856',
#   'domesticLifetimeGross': '$281,287,133',
#   'domestic': '39.5%',
#   'foreignLifetimeGross': '$430,918,723',
#   'foreign': '60.5%',
#   'year': '2011'},
#  {'id': 'tt1259571',
#   'rank': '121',
#   'title': 'The Twilight Saga: New Moon',
#   'worldwideLifetimeGross': '$711,025,481',
#   'domesticLifetimeGross': '$297,816,253',
#   'domestic': '41.9%',
#   'foreignLifetimeGross': '$413,209,228',
#   'foreign': '58.1%',
#   'year': '2009'},
#  {'id': 'tt2103281',
#   'rank': '122',
#   'title': 'Dawn of the Planet of the Apes',
#   'worldwideLifetimeGross': '$710,644,566',
#   'domesticLifetimeGross': '$208,545,589',
#   'domestic': '29.4%',
#   'foreignLifetimeGross': '$502,098,977',
#   'foreign': '70.6%',
#   'year': '2014'},
#  {'id': 'tt0418279',
#   'rank': '123',
#   'title': 'Transformers',
#   'worldwideLifetimeGross': '$709,709,780',
#   'domesticLifetimeGross': '$319,246,193',
#   'domestic': '45%',
#   'foreignLifetimeGross': '$390,463,587',
#   'foreign': '55%',
#   'year': '2007'},
#  {'id': 'tt1872181',
#   'rank': '124',
#   'title': 'The Amazing Spider-Man 2',
#   'worldwideLifetimeGross': '$708,982,323',
#   'domesticLifetimeGross': '$202,853,933',
#   'domestic': '28.6%',
#   'foreignLifetimeGross': '$506,128,390',
#   'foreign': '71.4%',
#   'year': '2014'},
#  {'id': 'tt1396484',
#   'rank': '125',
#   'title': 'It',
#   'worldwideLifetimeGross': '$701,796,444',
#   'domesticLifetimeGross': '$328,828,874',
#   'domestic': '46.9%',
#   'foreignLifetimeGross': '$372,967,570',
#   'foreign': '53.1%',
#   'year': '2017'},
#  {'id': 'tt0816692',
#   'rank': '126',
#   'title': 'Interstellar',
#   'worldwideLifetimeGross': '$701,729,206',
#   'domesticLifetimeGross': '$188,020,017',
#   'domestic': '26.8%',
#   'foreignLifetimeGross': '$513,709,189',
#   'foreign': '73.2%',
#   'year': '2014'},
#  {'id': 'tt7605074',
#   'rank': '127',
#   'title': 'The Wandering Earth',
#   'worldwideLifetimeGross': '$699,992,512',
#   'domesticLifetimeGross': '$5,971,413',
#   'domestic': '0.8%',
#   'foreignLifetimeGross': '$694,021,099',
#   'foreign': '99.2%',
#   'year': '2019'},
#  {'id': 'tt1325004',
#   'rank': '128',
#   'title': 'The Twilight Saga: Eclipse',
#   'worldwideLifetimeGross': '$698,491,347',
#   'domesticLifetimeGross': '$300,531,751',
#   'domestic': '43%',
#   'foreignLifetimeGross': '$397,959,596',
#   'foreign': '57%',
#   'year': '2010'},
#  {'id': 'tt1229238',
#   'rank': '129',
#   'title': 'Mission: Impossible - Ghost Protocol',
#   'worldwideLifetimeGross': '$694,713,380',
#   'domesticLifetimeGross': '$209,397,903',
#   'domestic': '30.1%',
#   'foreignLifetimeGross': '$485,315,477',
#   'foreign': '69.9%',
#   'year': '2011'},
#  {'id': 'tt1392170',
#   'rank': '130',
#   'title': 'The Hunger Games',
#   'worldwideLifetimeGross': '$694,394,724',
#   'domesticLifetimeGross': '$408,010,692',
#   'domestic': '58.8%',
#   'foreignLifetimeGross': '$286,384,032',
#   'foreign': '41.2%',
#   'year': '2012'},
#  {'id': 'tt10370822',
#   'rank': '131',
#   'title': 'Detective Chinatown 3',
#   'worldwideLifetimeGross': '$686,257,563',
#   'domesticLifetimeGross': '-',
#   'domestic': '-',
#   'foreignLifetimeGross': '$686,257,563',
#   'foreign': '100%',
#   'year': '2021'},
#  {'id': 'tt2381249',
#   'rank': '132',
#   'title': 'Mission: Impossible - Rogue Nation',
#   'worldwideLifetimeGross': '$682,716,636',
#   'domesticLifetimeGross': '$195,042,377',
#   'domestic': '28.6%',
#   'foreignLifetimeGross': '$487,674,259',
#   'foreign': '71.4%',
#   'year': '2015'},
#  {'id': 'tt0109830',
#   'rank': '133',
#   'title': 'Forrest Gump',
#   'worldwideLifetimeGross': '$678,226,133',
#   'domesticLifetimeGross': '$330,455,270',
#   'domestic': '48.7%',
#   'foreignLifetimeGross': '$347,770,863',
#   'foreign': '51.3%',
#   'year': '1994'},
#  {'id': 'tt1211837',
#   'rank': '134',
#   'title': 'Doctor Strange',
#   'worldwideLifetimeGross': '$677,796,076',
#   'domesticLifetimeGross': '$232,641,920',
#   'domestic': '34.3%',
#   'foreignLifetimeGross': '$445,154,156',
#   'foreign': '65.7%',
#   'year': '2016'},
#  {'id': 'tt0167404',
#   'rank': '135',
#   'title': 'The Sixth Sense',
#   'worldwideLifetimeGross': '$672,806,432',
#   'domesticLifetimeGross': '$293,506,292',
#   'domestic': '43.6%',
#   'foreignLifetimeGross': '$379,300,140',
#   'foreign': '56.4%',
#   'year': '1999'},
#  {'id': 'tt0770828',
#   'rank': '136',
#   'title': 'Man of Steel',
#   'worldwideLifetimeGross': '$668,045,518',
#   'domesticLifetimeGross': '$291,045,518',
#   'domestic': '43.6%',
#   'foreignLifetimeGross': '$377,000,000',
#   'foreign': '56.4%',
#   'year': '2013'},
#  {'id': 'tt0438097',
#   'rank': '137',
#   'title': 'Ice Age: The Meltdown',
#   'worldwideLifetimeGross': '$667,094,506',
#   'domesticLifetimeGross': '$195,330,621',
#   'domestic': '29.3%',
#   'foreignLifetimeGross': '$471,763,885',
#   'foreign': '70.7%',
#   'year': '2006'},
#  {'id': 'tt1302011',
#   'rank': '138',
#   'title': 'Kung Fu Panda 2',
#   'worldwideLifetimeGross': '$665,692,281',
#   'domesticLifetimeGross': '$165,249,063',
#   'domestic': '24.8%',
#   'foreignLifetimeGross': '$500,443,218',
#   'foreign': '75.2%',
#   'year': '2011'},
#  {'id': 'tt1951266',
#   'rank': '139',
#   'title': 'The Hunger Games: Mockingjay - Part 2',
#   'worldwideLifetimeGross': '$658,344,137',
#   'domesticLifetimeGross': '$281,723,902',
#   'domestic': '42.8%',
#   'foreignLifetimeGross': '$376,620,235',
#   'foreign': '57.2%',
#   'year': '2015'},
#  {'id': 'tt0974015',
#   'rank': '140',
#   'title': 'Justice League',
#   'worldwideLifetimeGross': '$657,926,987',
#   'domesticLifetimeGross': '$229,024,295',
#   'domestic': '34.8%',
#   'foreignLifetimeGross': '$428,902,692',
#   'foreign': '65.2%',
#   'year': '2017'},
#  {'id': 'tt2245084',
#   'rank': '141',
#   'title': 'Big Hero 6',
#   'worldwideLifetimeGross': '$657,869,686',
#   'domesticLifetimeGross': '$222,527,828',
#   'domestic': '33.8%',
#   'foreignLifetimeGross': '$435,341,858',
#   'foreign': '66.2%',
#   'year': '2014'},
#  {'id': 'tt4123430',
#   'rank': '142',
#   'title': 'Fantastic Beasts: The Crimes of Grindelwald',
#   'worldwideLifetimeGross': '$654,855,901',
#   'domesticLifetimeGross': '$159,555,901',
#   'domestic': '24.4%',
#   'foreignLifetimeGross': '$495,300,000',
#   'foreign': '75.6%',
#   'year': '2018'},
#  {'id': 'tt0325980',
#   'rank': '143',
#   'title': 'Pirates of the Caribbean: The Curse of the Black Pearl',
#   'worldwideLifetimeGross': '$654,264,015',
#   'domesticLifetimeGross': '$305,413,918',
#   'domestic': '46.7%',
#   'foreignLifetimeGross': '$348,850,097',
#   'foreign': '53.3%',
#   'year': '2003'},
#  {'id': 'tt0121765',
#   'rank': '144',
#   'title': 'Star Wars: Episode II - Attack of the Clones',
#   'worldwideLifetimeGross': '$653,779,970',
#   'domesticLifetimeGross': '$310,676,740',
#   'domestic': '47.5%',
#   'foreignLifetimeGross': '$343,103,230',
#   'foreign': '52.5%',
#   'year': '2002'},
#  {'id': 'tt1981115',
#   'rank': '145',
#   'title': 'Thor: The Dark World',
#   'worldwideLifetimeGross': '$644,783,140',
#   'domesticLifetimeGross': '$206,362,140',
#   'domestic': '32%',
#   'foreignLifetimeGross': '$438,421,000',
#   'foreign': '68%',
#   'year': '2013'},
#  {'id': 'tt3521164',
#   'rank': '146',
#   'title': 'Moana',
#   'worldwideLifetimeGross': '$644,136,488',
#   'domesticLifetimeGross': '$248,757,044',
#   'domestic': '38.6%',
#   'foreignLifetimeGross': '$395,379,444',
#   'foreign': '61.4%',
#   'year': '2016'},
#  {'id': 'tt3470600',
#   'rank': '147',
#   'title': 'Sing',
#   'worldwideLifetimeGross': '$634,208,384',
#   'domesticLifetimeGross': '$270,448,425',
#   'domestic': '42.6%',
#   'foreignLifetimeGross': '$363,759,959',
#   'foreign': '57.4%',
#   'year': '2016'},
#  {'id': 'tt0441773',
#   'rank': '148',
#   'title': 'Kung Fu Panda',
#   'worldwideLifetimeGross': '$631,746,197',
#   'domesticLifetimeGross': '$215,434,591',
#   'domestic': '34.1%',
#   'foreignLifetimeGross': '$416,311,606',
#   'foreign': '65.9%',
#   'year': '2008'},
#  {'id': 'tt0317705',
#   'rank': '149',
#   'title': 'The Incredibles',
#   'worldwideLifetimeGross': '$631,607,053',
#   'domesticLifetimeGross': '$261,441,092',
#   'domestic': '41.4%',
#   'foreignLifetimeGross': '$370,165,961',
#   'foreign': '58.6%',
#   'year': '2004'},
#  {'id': 'tt3659388',
#   'rank': '150',
#   'title': 'The Martian',
#   'worldwideLifetimeGross': '$630,162,448',
#   'domesticLifetimeGross': '$228,433,663',
#   'domestic': '36.2%',
#   'foreignLifetimeGross': '$401,728,785',
#   'foreign': '63.8%',
#   'year': '2015'},
#  {'id': 'tt0448157',
#   'rank': '151',
#   'title': 'Hancock',
#   'worldwideLifetimeGross': '$629,443,428',
#   'domesticLifetimeGross': '$227,946,274',
#   'domestic': '36.2%',
#   'foreignLifetimeGross': '$401,497,154',
#   'foreign': '63.8%',
#   'year': '2008'},
#  {'id': 'tt1596343',
#   'rank': '152',
#   'title': 'Fast Five',
#   'worldwideLifetimeGross': '$626,137,675',
#   'domesticLifetimeGross': '$209,837,675',
#   'domestic': '33.5%',
#   'foreignLifetimeGross': '$416,300,000',
#   'foreign': '66.5%',
#   'year': '2011'},
#  {'id': 'tt1409024',
#   'rank': '153',
#   'title': 'Men in Black 3',
#   'worldwideLifetimeGross': '$624,026,776',
#   'domesticLifetimeGross': '$179,020,854',
#   'domestic': '28.7%',
#   'foreignLifetimeGross': '$445,005,922',
#   'foreign': '71.3%',
#   'year': '2012'},
#  {'id': 'tt1228705',
#   'rank': '154',
#   'title': 'Iron Man 2',
#   'worldwideLifetimeGross': '$623,933,331',
#   'domesticLifetimeGross': '$312,433,331',
#   'domestic': '50.1%',
#   'foreignLifetimeGross': '$311,500,000',
#   'foreign': '49.9%',
#   'year': '2010'},
#  {'id': 'tt0382932',
#   'rank': '155',
#   'title': 'Ratatouille',
#   'worldwideLifetimeGross': '$623,726,085',
#   'domesticLifetimeGross': '$206,445,654',
#   'domestic': '33.1%',
#   'foreignLifetimeGross': '$417,280,431',
#   'foreign': '66.9%',
#   'year': '2007'},
#  {'id': 'tt5095030',
#   'rank': '156',
#   'title': 'Ant-Man and the Wasp',
#   'worldwideLifetimeGross': '$622,674,139',
#   'domesticLifetimeGross': '$216,648,740',
#   'domestic': '34.8%',
#   'foreignLifetimeGross': '$406,025,399',
#   'foreign': '65.2%',
#   'year': '2018'},
#  {'id': 'tt1646971',
#   'rank': '157',
#   'title': 'How to Train Your Dragon 2',
#   'worldwideLifetimeGross': '$621,537,519',
#   'domesticLifetimeGross': '$177,002,924',
#   'domestic': '28.5%',
#   'foreignLifetimeGross': '$444,534,595',
#   'foreign': '71.5%',
#   'year': '2014'},
#  {'id': 'tt3315342',
#   'rank': '158',
#   'title': 'Logan',
#   'worldwideLifetimeGross': '$619,179,950',
#   'domesticLifetimeGross': '$226,277,068',
#   'domestic': '36.5%',
#   'foreignLifetimeGross': '$392,902,882',
#   'foreign': '63.5%',
#   'year': '2017'},
#  {'id': 'tt0119567',
#   'rank': '159',
#   'title': 'The Lost World: Jurassic Park',
#   'worldwideLifetimeGross': '$618,638,999',
#   'domesticLifetimeGross': '$229,086,679',
#   'domestic': '37%',
#   'foreignLifetimeGross': '$389,552,320',
#   'foreign': '63%',
#   'year': '1997'},
#  {'id': 'tt0381061',
#   'rank': '160',
#   'title': 'Casino Royale',
#   'worldwideLifetimeGross': '$616,502,912',
#   'domesticLifetimeGross': '$167,445,960',
#   'domestic': '27.2%',
#   'foreignLifetimeGross': '$449,056,952',
#   'foreign': '72.8%',
#   'year': '2006'},
#  {'id': 'tt0335345',
#   'rank': '161',
#   'title': 'The Passion of the Christ',
#   'worldwideLifetimeGross': '$612,054,506',
#   'domesticLifetimeGross': '$370,782,930',
#   'domestic': '60.6%',
#   'foreignLifetimeGross': '$241,271,576',
#   'foreign': '39.4%',
#   'year': '2004'},
#  {'id': 'tt0795421',
#   'rank': '162',
#   'title': 'Mamma Mia!',
#   'worldwideLifetimeGross': '$611,257,819',
#   'domesticLifetimeGross': '$144,169,664',
#   'domestic': '23.6%',
#   'foreignLifetimeGross': '$467,088,155',
#   'foreign': '76.4%',
#   'year': '2008'},
#  {'id': 'tt0454876',
#   'rank': '163',
#   'title': 'Life of Pi',
#   'worldwideLifetimeGross': '$609,016,565',
#   'domesticLifetimeGross': '$124,987,023',
#   'domestic': '20.5%',
#   'foreignLifetimeGross': '$484,029,542',
#   'foreign': '79.5%',
#   'year': '2012'},
#  {'id': 'tt2382320',
#   'rank': '164',
#   'title': 'No Time to Die',
#   'worldwideLifetimeGross': '$607,583,451',
#   'domesticLifetimeGross': '$134,111,451',
#   'domestic': '22.1%',
#   'foreignLifetimeGross': '$473,472,000',
#   'foreign': '77.9%',
#   'year': '2021'},
#  {'id': 'tt3371366',
#   'rank': '165',
#   'title': 'Transformers: The Last Knight',
#   'worldwideLifetimeGross': '$605,425,157',
#   'domesticLifetimeGross': '$130,168,683',
#   'domestic': '21.5%',
#   'foreignLifetimeGross': '$475,256,474',
#   'foreign': '78.5%',
#   'year': '2017'},
#  {'id': 'tt0479952',
#   'rank': '166',
#   'title': 'Madagascar: Escape 2 Africa',
#   'worldwideLifetimeGross': '$603,900,354',
#   'domesticLifetimeGross': '$180,010,950',
#   'domestic': '29.8%',
#   'foreignLifetimeGross': '$423,889,404',
#   'foreign': '70.2%',
#   'year': '2008'},
#  {'id': 'tt0407304',
#   'rank': '167',
#   'title': 'War of the Worlds',
#   'worldwideLifetimeGross': '$603,873,119',
#   'domesticLifetimeGross': '$234,280,354',
#   'domestic': '38.8%',
#   'foreignLifetimeGross': '$369,592,765',
#   'foreign': '61.2%',
#   'year': '2005'},
#  {'id': 'tt0398286',
#   'rank': '168',
#   'title': 'Tangled',
#   'worldwideLifetimeGross': '$592,462,816',
#   'domesticLifetimeGross': '$200,821,936',
#   'domestic': '33.9%',
#   'foreignLifetimeGross': '$391,640,880',
#   'foreign': '66.1%',
#   'year': '2010'},
#  {'id': 'tt0830515',
#   'rank': '169',
#   'title': 'Quantum of Solace',
#   'worldwideLifetimeGross': '$589,580,482',
#   'domesticLifetimeGross': '$168,368,427',
#   'domestic': '28.6%',
#   'foreignLifetimeGross': '$421,212,055',
#   'foreign': '71.4%',
#   'year': '2008'},
#  {'id': 'tt0119654',
#   'rank': '170',
#   'title': 'Men in Black',
#   'worldwideLifetimeGross': '$589,390,539',
#   'domesticLifetimeGross': '$250,690,539',
#   'domestic': '42.5%',
#   'foreignLifetimeGross': '$338,700,000',
#   'foreign': '57.5%',
#   'year': '1997'},
#  {'id': 'tt0481499',
#   'rank': '171',
#   'title': 'The Croods',
#   'worldwideLifetimeGross': '$587,235,983',
#   'domesticLifetimeGross': '$187,168,425',
#   'domestic': '31.9%',
#   'foreignLifetimeGross': '$400,067,558',
#   'foreign': '68.1%',
#   'year': '2013'},
#  {'id': 'tt1411697',
#   'rank': '172',
#   'title': 'The Hangover Part II',
#   'worldwideLifetimeGross': '$586,764,305',
#   'domesticLifetimeGross': '$254,464,305',
#   'domestic': '43.4%',
#   'foreignLifetimeGross': '$332,300,000',
#   'foreign': '56.6%',
#   'year': '2011'},
#  {'id': 'tt0371746',
#   'rank': '173',
#   'title': 'Iron Man',
#   'worldwideLifetimeGross': '$585,796,247',
#   'domesticLifetimeGross': '$319,034,126',
#   'domestic': '54.5%',
#   'foreignLifetimeGross': '$266,762,121',
#   'foreign': '45.5%',
#   'year': '2008'},
#  {'id': 'tt0480249',
#   'rank': '174',
#   'title': 'I Am Legend',
#   'worldwideLifetimeGross': '$585,410,052',
#   'domesticLifetimeGross': '$256,393,010',
#   'domestic': '43.8%',
#   'foreignLifetimeGross': '$329,017,042',
#   'foreign': '56.2%',
#   'year': '2007'},
#  {'id': 'tt1677720',
#   'rank': '175',
#   'title': 'Ready Player One',
#   'worldwideLifetimeGross': '$582,893,671',
#   'domesticLifetimeGross': '$137,690,172',
#   'domestic': '23.6%',
#   'foreignLifetimeGross': '$445,203,499',
#   'foreign': '76.4%',
#   'year': '2018'},
#  {'id': 'tt0198781',
#   'rank': '176',
#   'title': 'Monsters, Inc.',
#   'worldwideLifetimeGross': '$579,707,738',
#   'domesticLifetimeGross': '$290,642,256',
#   'domestic': '50.1%',
#   'foreignLifetimeGross': '$289,065,482',
#   'foreign': '49.9%',
#   'year': '2001'},
#  {'id': 'tt6878882',
#   'rank': '177',
#   'title': 'Operation Red Sea',
#   'worldwideLifetimeGross': '$579,330,426',
#   'domesticLifetimeGross': '$1,543,547',
#   'domestic': '0.3%',
#   'foreignLifetimeGross': '$577,786,879',
#   'foreign': '99.7%',
#   'year': '2018'},
#  {'id': 'tt0477347',
#   'rank': '178',
#   'title': 'Night at the Museum',
#   'worldwideLifetimeGross': '$574,481,229',
#   'domesticLifetimeGross': '$250,863,268',
#   'domestic': '43.7%',
#   'foreignLifetimeGross': '$323,617,961',
#   'foreign': '56.3%',
#   'year': '2006'},
#  {'id': 'tt2322441',
#   'rank': '179',
#   'title': 'Fifty Shades of Grey',
#   'worldwideLifetimeGross': '$569,651,467',
#   'domesticLifetimeGross': '$166,167,230',
#   'domestic': '29.2%',
#   'foreignLifetimeGross': '$403,484,237',
#   'foreign': '70.8%',
#   'year': '2015'},
#  {'id': 'tt3731562',
#   'rank': '180',
#   'title': 'Kong: Skull Island',
#   'worldwideLifetimeGross': '$566,652,812',
#   'domesticLifetimeGross': '$168,052,812',
#   'domestic': '29.7%',
#   'foreignLifetimeGross': '$398,600,000',
#   'foreign': '70.3%',
#   'year': '2017'},
#  {'id': 'tt0472181',
#   'rank': '181',
#   'title': 'The Smurfs',
#   'worldwideLifetimeGross': '$563,749,323',
#   'domesticLifetimeGross': '$142,614,158',
#   'domestic': '25.3%',
#   'foreignLifetimeGross': '$421,135,165',
#   'foreign': '74.7%',
#   'year': '2011'},
#  {'id': 'tt1216475',
#   'rank': '182',
#   'title': 'Cars 2',
#   'worldwideLifetimeGross': '$559,852,396',
#   'domesticLifetimeGross': '$191,452,396',
#   'domestic': '34.2%',
#   'foreignLifetimeGross': '$368,400,000',
#   'foreign': '65.8%',
#   'year': '2011'},
#  {'id': 'tt0360717',
#   'rank': '183',
#   'title': 'King Kong',
#   'worldwideLifetimeGross': '$556,906,378',
#   'domesticLifetimeGross': '$218,080,025',
#   'domestic': '39.2%',
#   'foreignLifetimeGross': '$338,826,353',
#   'foreign': '60.8%',
#   'year': '2005'},
#  {'id': 'tt0448694',
#   'rank': '184',
#   'title': 'Puss in Boots',
#   'worldwideLifetimeGross': '$554,987,477',
#   'domesticLifetimeGross': '$149,260,504',
#   'domestic': '26.9%',
#   'foreignLifetimeGross': '$405,726,973',
#   'foreign': '73.1%',
#   'year': '2011'},
#  {'id': 'tt4701660',
#   'rank': '185',
#   'title': 'The Mermaid',
#   'worldwideLifetimeGross': '$553,810,228',
#   'domesticLifetimeGross': '$3,232,685',
#   'domestic': '0.6%',
#   'foreignLifetimeGross': '$550,577,543',
#   'foreign': '99.4%',
#   'year': '2016'},
#  {'id': 'tt0120591',
#   'rank': '186',
#   'title': 'Armageddon',
#   'worldwideLifetimeGross': '$553,709,788',
#   'domesticLifetimeGross': '$201,578,182',
#   'domestic': '36.4%',
#   'foreignLifetimeGross': '$352,131,606',
#   'foreign': '63.6%',
#   'year': '1998'},
#  {'id': 'tt0319262',
#   'rank': '187',
#   'title': 'The Day After Tomorrow',
#   'worldwideLifetimeGross': '$552,639,571',
#   'domesticLifetimeGross': '$186,740,799',
#   'domestic': '33.8%',
#   'foreignLifetimeGross': '$365,898,772',
#   'foreign': '66.2%',
#   'year': '2004'},
#  {'id': 'tt1637725',
#   'rank': '188',
#   'title': 'Ted',
#   'worldwideLifetimeGross': '$549,368,315',
#   'domesticLifetimeGross': '$218,815,487',
#   'domestic': '39.8%',
#   'foreignLifetimeGross': '$330,552,828',
#   'foreign': '60.2%',
#   'year': '2012'},
#  {'id': 'tt2179136',
#   'rank': '189',
#   'title': 'American Sniper',
#   'worldwideLifetimeGross': '$547,426,372',
#   'domesticLifetimeGross': '$350,126,372',
#   'domestic': '64%',
#   'foreignLifetimeGross': '$197,300,000',
#   'foreign': '36%',
#   'year': '2014'},
#  {'id': 'tt0120755',
#   'rank': '190',
#   'title': 'Mission: Impossible II',
#   'worldwideLifetimeGross': '$546,388,108',
#   'domesticLifetimeGross': '$215,409,889',
#   'domestic': '39.4%',
#   'foreignLifetimeGross': '$330,978,219',
#   'foreign': '60.6%',
#   'year': '2000'},
#  {'id': 'tt7752454',
#   'rank': '191',
#   'title': 'Detective Chinatown 2',
#   'worldwideLifetimeGross': '$544,185,156',
#   'domesticLifetimeGross': '$1,983,984',
#   'domestic': '0.4%',
#   'foreignLifetimeGross': '$542,201,172',
#   'foreign': '99.6%',
#   'year': '2018'},
#  {'id': 'tt3385516',
#   'rank': '192',
#   'title': 'X-Men: Apocalypse',
#   'worldwideLifetimeGross': '$543,934,105',
#   'domesticLifetimeGross': '$155,442,489',
#   'domestic': '28.6%',
#   'foreignLifetimeGross': '$388,491,616',
#   'foreign': '71.4%',
#   'year': '2016'},
#  {'id': 'tt1515091',
#   'rank': '193',
#   'title': 'Sherlock Holmes: A Game of Shadows',
#   'worldwideLifetimeGross': '$543,848,418',
#   'domesticLifetimeGross': '$186,848,418',
#   'domestic': '34.4%',
#   'foreignLifetimeGross': '$357,000,000',
#   'foreign': '65.6%',
#   'year': '2011'},
#  {'id': 'tt1323594',
#   'rank': '194',
#   'title': 'Despicable Me',
#   'worldwideLifetimeGross': '$543,113,985',
#   'domesticLifetimeGross': '$251,513,985',
#   'domestic': '46.3%',
#   'foreignLifetimeGross': '$291,600,000',
#   'foreign': '53.7%',
#   'year': '2010'},
#  {'id': 'tt1661199',
#   'rank': '195',
#   'title': 'Cinderella',
#   'worldwideLifetimeGross': '$542,358,331',
#   'domesticLifetimeGross': '$201,151,353',
#   'domestic': '37.1%',
#   'foreignLifetimeGross': '$341,206,978',
#   'foreign': '62.9%',
#   'year': '2015'},
#  {'id': 'tt0351283',
#   'rank': '196',
#   'title': 'Madagascar',
#   'worldwideLifetimeGross': '$542,063,846',
#   'domesticLifetimeGross': '$193,595,521',
#   'domestic': '35.7%',
#   'foreignLifetimeGross': '$348,468,325',
#   'foreign': '64.3%',
#   'year': '2005'},
#  {'id': 'tt0816711',
#   'rank': '197',
#   'title': 'World War Z',
#   'worldwideLifetimeGross': '$540,455,876',
#   'domesticLifetimeGross': '$202,807,711',
#   'domestic': '37.5%',
#   'foreignLifetimeGross': '$337,648,165',
#   'foreign': '62.5%',
#   'year': '2013'},
#  {'id': 'tt1217209',
#   'rank': '198',
#   'title': 'Brave',
#   'worldwideLifetimeGross': '$538,983,207',
#   'domesticLifetimeGross': '$237,283,207',
#   'domestic': '44%',
#   'foreignLifetimeGross': '$301,700,000',
#   'foreign': '56%',
#   'year': '2012'},
#  {'id': 'tt0080684',
#   'rank': '199',
#   'title': 'Star Wars: Episode V - The Empire Strikes Back',
#   'worldwideLifetimeGross': '$538,375,067',
#   'domesticLifetimeGross': '$292,753,960',
#   'domestic': '54.4%',
#   'foreignLifetimeGross': '$245,621,107',
#   'foreign': '45.6%',
#   'year': '1980'},
#  {'id': 'tt0462538',
#   'rank': '200',
#   'title': 'The Simpsons Movie',
#   'worldwideLifetimeGross': '$536,414,293',
#   'domesticLifetimeGross': '$183,135,014',
#   'domestic': '34.1%',
#   'foreignLifetimeGross': '$353,279,279',
#   'foreign': '65.9%',
#   'year': '2007'}]

# %%
#includes top 100 grossing movies of all time
len(response2['items'])

data_list2 = response2['items']
column_names2 = list(data_list2[0].keys())
column_names2
# Out:
# ['id',
#  'rank',
#  'title',
#  'worldwideLifetimeGross',
#  'domesticLifetimeGross',
#  'domestic',
#  'foreignLifetimeGross',
#  'foreign',
#  'year']

# %%
top_grossing_df = pd.DataFrame(data=data_list2, columns=column_names2)
top_grossing_df.head(25)
# Out:
#            id rank                                          title  \
# 0   tt0499549    1                                         Avatar
# 1   tt4154796    2                              Avengers: Endgame
# 2   tt0120338    3                                        Titanic
# 3   tt2488496    4     Star Wars: Episode VII - The Force Awakens
# 4   tt4154756    5                         Avengers: Infinity War
# 5   tt0369610    6                                 Jurassic World
# 6   tt6105098    7                                  The Lion King
# 7   tt0848228    8                                   The Avengers
# 8   tt2820852    9                                      Furious 7
# 9   tt4520988   10                                      Frozen II
# 10  tt2395427   11                        Avengers: Age of Ultron
# 11  tt1825683   12                                  Black Panther
# 12  tt1201607   13   Harry Potter and the Deathly Hallows: Part 2
# 13  tt2527336   14        Star Wars: Episode VIII - The Last Jedi
# 14  tt4881806   15                 Jurassic World: Fallen Kingdom
# 15  tt2294629   16                                         Frozen
# 16  tt2771200   17                           Beauty and the Beast
# 17  tt3606756   18                                  Incredibles 2
# 18  tt4630562   19                        The Fate of the Furious
# 19  tt1300854   20                                     Iron Man 3
# 20  tt2293640   21                                        Minions
# 21  tt3498820   22                     Captain America: Civil War
# 22  tt1477834   23                                        Aquaman
# 23  tt0167260   24  The Lord of the Rings: The Return of the King
# 24  tt6320628   25                      Spider-Man: Far from Home
#
#    worldwideLifetimeGross domesticLifetimeGross domestic foreignLifetimeGross  \
# 0          $2,847,246,203          $760,507,625    26.7%       $2,086,738,578
# 1          $2,797,501,328          $858,373,000    30.7%       $1,939,128,328
# 2          $2,201,647,264          $659,363,944      30%       $1,542,283,320
# 3          $2,069,521,700          $936,662,225    45.3%       $1,132,859,475
# 4          $2,048,359,754          $678,815,482    33.1%       $1,369,544,272
# 5          $1,670,516,444          $652,385,625      39%       $1,018,130,819
# 6          $1,667,635,327          $543,638,043    32.6%       $1,123,997,284
# 7          $1,518,815,515          $623,357,910      41%         $895,457,605
# 8          $1,515,341,399          $353,007,020    23.3%       $1,162,334,379
# 9          $1,450,026,933          $477,373,578    32.9%         $972,653,355
# 10         $1,402,809,540          $459,005,868    32.7%         $943,803,672
# 11         $1,347,597,973          $700,426,566      52%         $647,171,407
# 12         $1,342,321,665          $381,409,310    28.4%         $960,912,355
# 13         $1,332,698,830          $620,181,382    46.5%         $712,517,448
# 14         $1,310,466,296          $417,719,760    31.9%         $892,746,536
# 15         $1,281,508,100          $400,953,009    31.3%         $880,555,091
# 16         $1,273,576,220          $504,481,165    39.6%         $769,095,055
# 17         $1,244,639,527          $608,581,744    48.9%         $636,057,783
# 18         $1,236,005,118          $226,008,385    18.3%       $1,009,996,733
# 19         $1,214,811,252          $409,013,994    33.7%         $805,797,258
# 20         $1,159,444,662          $336,045,770      29%         $823,398,892
# 21         $1,153,337,496          $408,084,349    35.4%         $745,253,147
# 22         $1,148,485,886          $335,061,807    29.2%         $813,424,079
# 23         $1,146,030,912          $377,845,905      33%         $768,185,007
# 24         $1,131,927,996          $390,532,085    34.5%         $741,395,911
#
#    foreign  year
# 0    73.3%  2009
# 1    69.3%  2019
# 2      70%  1997
# 3    54.7%  2015
# 4    66.9%  2018
# 5      61%  2015
# 6    67.4%  2019
# 7      59%  2012
# 8    76.7%  2015
# 9    67.1%  2019
# 10   67.3%  2015
# 11     48%  2018
# 12   71.6%  2011
# 13   53.5%  2017
# 14   68.1%  2018
# 15   68.7%  2013
# 16   60.4%  2017
# 17   51.1%  2018
# 18   81.7%  2017
# 19   66.3%  2013
# 20     71%  2015
# 21   64.6%  2016
# 22   70.8%  2018
# 23     67%  2003
# 24   65.5%  2019

# %% [markdown]
# # Objective #4: What are the top films of 2021?

# %%
#Wnat to try to use webscraping to pull the info of the top films of 2021 using 
#Box Office MoJo

from bs4 import BeautifulSoup
import re
html_page = requests.get("https://www.boxofficemojo.com/year/2021/?ref_=bo_lnav_hm_shrt")

soup = BeautifulSoup(html_page.content, 'html.parser')

# %%
#finding relevant division and creating container
table = soup.find('div', id='table')

#seperates all the relevant rows with movie data from table headers
table_rows = table.findAll('tr')[1:]

#length outputs 200 items, which corresponds to the 200 items on the website
len(table_rows)
# Out:
# 200

# %%
#Now to extract information from the first row to serve as a template for
#other rows 
table_rows[0]
# Out:
# <tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank mojo-sort-column">1</td><td class="a-text-left mojo-field-type-release mojo-cell-wide"><a class="a-link-normal" href="/release/rl3490022913/?ref_=bo_yld_table_1">Shang-Chi and the Legend of the Ten Rings</a></td><td class="a-text-left mojo-field-type-genre hidden">-</td><td class="a-text-right mojo-field-type-money hidden">-</td><td class="a-text-right mojo-field-type-duration hidden">-</td><td class="a-text-right mojo-field-type-money mojo-estimatable">$221,356,951</td><td class="a-text-right mojo-field-type-positive_integer">4,300</td><td class="a-text-right mojo-field-type-money mojo-estimatable">$221,356,951</td><td class="a-text-left mojo-field-type-date a-nowrap">Sep 3</td><td class="a-text-left mojo-field-type-studio"><a class="a-link-normal" href="https://pro.imdb.com/company/co0226183/boxoffice/?view=releases&amp;ref_=mojo_yld_table_1&amp;rf=mojo_yld_table_1" rel="noopener" target="_blank">Walt Disney Studios Motion Pictures<svg class="mojo-new-window-svg" viewbox="0 0 32 32" xmlns="http://www.w3.org/2000/svg">
# <path d="M24,15.57251l3,3V23.5A3.50424,3.50424,0,0,1,23.5,27H8.5A3.50424,3.50424,0,0,1,5,23.5V8.5A3.50424,3.50424,0,0,1,8.5,5h4.92755l3,3H8.5a.50641.50641,0,0,0-.5.5v15a.50641.50641,0,0,0,.5.5h15a.50641.50641,0,0,0,.5-.5ZM19.81952,8.56372,12.8844,17.75a.49989.49989,0,0,0,.04547.65479l.66534.66528a.49983.49983,0,0,0,.65479.04553l9.18628-6.93518,2.12579,2.12585a.5.5,0,0,0,.84741-.27526l1.48273-9.35108a.50006.50006,0,0,0-.57214-.57214L17.969,5.59058a.5.5,0,0,0-.27526.84741Z"></path>
# </svg></a></td><td class="a-text-right mojo-field-type-boolean hidden">false</td></tr>

# %%
#finding rank
rank = table_rows[0].find('td', class_="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank mojo-sort-column").text
rank
# Out:
# '1'

# %%
#finding title
title = table_rows[0].find('td', class_= "a-text-left mojo-field-type-release mojo-cell-wide").text
title
# Out:
# 'Shang-Chi and the Legend of the Ten Rings'

# %%
#finding amount grossed
gross = table_rows[0].find('td', class_ = "a-text-right mojo-field-type-money mojo-estimatable").text
gross
# Out:
# '$222,889,137'

# %%
#finding release data
release_date = table_rows[0].find('td', class_ = "a-text-left mojo-field-type-date a-nowrap").text
release_date
# Out:
# 'Sep 3'

# %%
#finding studio
studio =  table_rows[0].find('td',class_ = "a-text-left mojo-field-type-studio").text.strip()
studio
# Out:
# 'Walt Disney Studios Motion Pictures'

# %%
def get_movie_data(movie_table):
    movie_data = []
    for row in movie_table:
        rank = row.find('td', class_="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank mojo-sort-column").text
        title = row.find('td', class_= "a-text-left mojo-field-type-release mojo-cell-wide").text
        gross = row.find('td', class_ = "a-text-right mojo-field-type-money mojo-estimatable").text
        release_date = row.find('td', class_ = "a-text-left mojo-field-type-date a-nowrap").text
        studio = row.find('td',class_ = "a-text-left mojo-field-type-studio").text.strip()
        
        movie_data.append({'Rank': rank, 'Title': title, 'Gross': gross, 
                           'Release Date': release_date, 'Studio': studio})
    return movie_data

# %%
movie_data = get_movie_data(table_rows)

# %%
rankings_df = pd.DataFrame(movie_data)

# %%
#Creating money_cleaner function to remove '$', ',', and convert to integer for
#easier analysis
def money_cleaner(df, column_name, new_col_name):
    df[new_col_name] = df[column_name].map(lambda x: x.replace('$', ''))
    df[new_col_name] = df[new_col_name].map(lambda x: x.replace(',', ''))
    df[new_col_name] = pd.to_numeric(df[new_col_name])
    
    return df[new_col_name]

# %%
#applying money_cleaner function to gross column
gross_clean = money_cleaner(rankings_df, 'Gross', 'Gross_Clean')

#adds column to existing df
rankings_df['Gross_Clean'] = gross_clean
rankings_df.head()
# Out:
#   Rank                                      Title         Gross Release Date  \
# 0    1  Shang-Chi and the Legend of the Ten Rings  $222,889,137        Sep 3
# 1    2                Venom: Let There Be Carnage  $191,000,953        Oct 1
# 2    3                                Black Widow  $183,651,655        Jul 9
# 3    4                          F9: The Fast Saga  $173,005,945       Jun 25
# 4    5                      A Quiet Place Part II  $160,072,261       May 28
#
#                                 Studio  Gross_Clean
# 0  Walt Disney Studios Motion Pictures    222889137
# 1    Sony Pictures Entertainment (SPE)    191000953
# 2  Walt Disney Studios Motion Pictures    183651655
# 3                   Universal Pictures    173005945
# 4                   Paramount Pictures    160072261

# %%
rankings_df[:25]
# Out:
#    Rank                                      Title         Gross Release Date  \
# 0     1  Shang-Chi and the Legend of the Ten Rings  $222,889,137        Sep 3
# 1     2                Venom: Let There Be Carnage  $191,000,953        Oct 1
# 2     3                                Black Widow  $183,651,655        Jul 9
# 3     4                          F9: The Fast Saga  $173,005,945       Jun 25
# 4     5                      A Quiet Place Part II  $160,072,261       May 28
# 5     6                             No Time to Die  $134,111,451        Oct 8
# 6     7                                   Free Guy  $121,399,463       Aug 13
# 7     8                              Jungle Cruise  $116,901,135       Jul 30
# 8     9                          Godzilla vs. Kong   $99,244,744       Mar 31
# 9    10                            Halloween Kills   $86,348,210       Oct 15
# 10   11                                    Cruella   $86,103,234       May 28
# 11   12                    Space Jam: A New Legacy   $67,495,028       Jul 16
# 12   13     The Conjuring: The Devil Made Me Do It   $65,513,102        Jun 4
# 13   14                                   Candyman   $61,147,405       Aug 27
# 14   15             The Boss Baby: Family Business   $57,300,280        Jul 2
# 15   16                                       Dune   $57,258,939       Oct 22
# 16   17                          The Suicide Squad   $55,795,457        Aug 6
# 17   18                   Raya and the Last Dragon   $54,723,032        Mar 5
# 18   19                        The Addams Family 2   $52,907,732        Oct 1
# 19   20                                        Old   $48,242,510       Jul 23
# 20   21                              Tom and Jerry   $45,822,877       Feb 26
# 21   22                          The Forever Purge   $44,539,245        Jul 2
# 22   23                Peter Rabbit 2: The Runaway   $40,336,536       Jun 11
# 23   24                      PAW Patrol: The Movie   $40,127,371       Aug 20
# 24   25                  Hitman's Wife's Bodyguard   $38,014,727       Jun 16
#
#                                  Studio  Gross_Clean
# 0   Walt Disney Studios Motion Pictures    222889137
# 1     Sony Pictures Entertainment (SPE)    191000953
# 2   Walt Disney Studios Motion Pictures    183651655
# 3                    Universal Pictures    173005945
# 4                    Paramount Pictures    160072261
# 5             Metro-Goldwyn-Mayer (MGM)    134111451
# 6                  20th Century Studios    121399463
# 7   Walt Disney Studios Motion Pictures    116901135
# 8                          Warner Bros.     99244744
# 9                    Universal Pictures     86348210
# 10  Walt Disney Studios Motion Pictures     86103234
# 11                         Warner Bros.     67495028
# 12                         Warner Bros.     65513102
# 13                   Universal Pictures     61147405
# 14                   Universal Pictures     57300280
# 15                         Warner Bros.     57258939
# 16                         Warner Bros.     55795457
# 17  Walt Disney Studios Motion Pictures     54723032
# 18             United Artists Releasing     52907732
# 19                   Universal Pictures     48242510
# 20                         Warner Bros.     45822877
# 21                   Universal Pictures     44539245
# 22    Sony Pictures Entertainment (SPE)     40336536
# 23                   Paramount Pictures     40127371
# 24                            Lionsgate     38014727

# %% [markdown]
# # Objective #5: Which studios have been the most successful in 2021? How much have the grossed?

# %%
#sorts by the studio name and then sums the values of total gross per studio
studio_gross = rankings_df.groupby('Studio').sum('Gross_Clean').sort_values(by='Gross_Clean', ascending=False)

#creates new df of the top 10 grossing studios 
top_10_gross = studio_gross[:10]

# %%
#Creates horizontal bargraph visualiation

ax = studio_gross[:10].plot(kind='barh', figsize=(15, 6))
ax.set_xlabel('2021 Domestic Gross Total')
ax.xaxis.set_major_formatter("{x:,.2f}")
ax.legend(['Domestic Gross in $'], loc='upper right')
ax.set_title('Total Grossed per Studio in 2021');

# %% [markdown]
# # Objective 5: What is the average budget of top movies?

# %%
#Uploads data about movie budgets
df = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
#Uses money cleaner function to clean data for statistical analysis
budget_clean = money_cleaner(df, 'production_budget', 'budget_clean')
df['budget_clean'] = budget_clean

worldwide_gross = money_cleaner(df, 'worldwide_gross', 'ww_gross_clean')
df['ww_gross_clean'] = worldwide_gross
df.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross  budget_clean  \
# 0      $425,000,000   $760,507,625  $2,776,345,279     425000000
# 1      $410,600,000   $241,063,875  $1,045,663,875     410600000
# 2      $350,000,000    $42,762,350    $149,762,350     350000000
# 3      $330,600,000   $459,005,868  $1,403,013,963     330600000
# 4      $317,000,000   $620,181,382  $1,316,721,747     317000000
#
#    ww_gross_clean
# 0      2776345279
# 1      1045663875
# 2       149762350
# 3      1403013963
# 4      1316721747

# %%
df['production_profit'] = df.ww_gross_clean - df.budget_clean

# %%
df.sort_values(by='production_profit', ascending=False)
# Out:
#      id  release_date                                 movie production_budget  \
# 0     1  Dec 18, 2009                                Avatar      $425,000,000
# 42   43  Dec 19, 1997                               Titanic      $200,000,000
# 6     7  Apr 27, 2018                Avengers: Infinity War      $300,000,000
# 5     6  Dec 18, 2015  Star Wars Ep. VII: The Force Awakens      $306,000,000
# 33   34  Jun 12, 2015                        Jurassic World      $215,000,000
# ..   ..           ...                                   ...               ...
# 352  53  Apr 27, 2001                        Town & Country      $105,000,000
# 341  42  Jun 14, 2019           Men in Black: International      $110,000,000
# 193  94  Mar 11, 2011                       Mars Needs Moms      $150,000,000
# 194  95  Dec 31, 2020                              Moonfall      $150,000,000
# 2     3   Jun 7, 2019                          Dark Phoenix      $350,000,000
#
#     domestic_gross worldwide_gross  budget_clean  ww_gross_clean  \
# 0     $760,507,625  $2,776,345,279     425000000      2776345279
# 42    $659,363,944  $2,208,208,395     200000000      2208208395
# 6     $678,815,482  $2,048,134,200     300000000      2048134200
# 5     $936,662,225  $2,053,311,220     306000000      2053311220
# 33    $652,270,625  $1,648,854,864     215000000      1648854864
# ..             ...             ...           ...             ...
# 352     $6,712,451     $10,364,769     105000000        10364769
# 341     $3,100,000      $3,100,000     110000000         3100000
# 193    $21,392,758     $39,549,758     150000000        39549758
# 194             $0              $0     150000000               0
# 2      $42,762,350    $149,762,350     350000000       149762350
#
#      production_profit
# 0           2351345279
# 42          2008208395
# 6           1748134200
# 5           1747311220
# 33          1433854864
# ..                 ...
# 352          -94635231
# 341         -106900000
# 193         -110450242
# 194         -150000000
# 2           -200237650
#
# [5782 rows x 9 columns]

# %%
#Creates visual to see if there is a correlation between budget and profit. 
# Will movies with higher budgets have higher profits as well?

budget = df['budget_clean']
profit = df['production_profit']


ax = sns.regplot(x=budget, y=profit)


ax.get_figure().set_size_inches((11, 8.5))
ax.set_xlabel('Movie Budget')
ax.set_ylabel('Movie Profit')
#ax1.xaxis.set_major_formatter("{x:,.2f}")
#ax2.yaxis.set_minor_formatter("{y:,.2f}")
ax.set_title("Movie Budget vs Profit");

# %%
animation = [False, False, False, False, False, False, False, True, True, True,
            False, True, False, False, False, False, False, False, False, True,
            False, True, True, True, True, False, True, False, True, False, 
            False, False, True, False, True, False, False, False, True, False, 
             False, False, False, False, False, True, False, False, False, False,
            False, False, True, False, True, False, True, False, False, False,
            False, False, False, False, False, False, False, True, False, False,
            False, False, True, False, False, True, True, False, False, False,
            False, True, False, True, False, False, True, False, False, True,
            False, True, False, True, False, True, True, False, True, False]

len(animation)
# Out:
# 100
